# %% [markdown]
# # Business Problem:

# %% [markdown]
# ## Background

# %% [markdown]
# In Tanzania Half of the population does not have access to clean water. The Tanzania Ministry of Water is trying to tackle the freshwater problem by installing water pumps through coordination of various charitable and government organizations. However, a significant part of water pumps are entirely out of order or do not function; the others require repair.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# We need to develop a ternary classification model to help the Tanzania Ministry of Water to predict which water pumps are functional, which need some repairs, and which don't work at all.  A smart understanding of which waterpoints will fail can improve maintenance operations and ensure that clean, potable water is available to communities across Tanzania.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
# import xgboost as xgb
import catboost
import time
import warnings
warnings.filterwarnings('ignore')

from sklearn.utils import class_weight
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from catboost import Pool, sum_models
from catboost import CatBoostClassifier
from statsmodels.formula.api import ols
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, balanced_accuracy_score
from sklearn.model_selection import KFold, cross_val_score, StratifiedKFold
from sklearn.preprocessing import LabelEncoder,  OneHotEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Data Exploration

# %%
df_test = pd.read_csv('data/Test-set-values.csv')

# %%
df_train_set = pd.read_csv('data/Training-set-values.csv')
df_train_labels = pd.read_csv('data/Training-set-labels.csv')

# %% [markdown]
# ## Data Fields

# %% [markdown]
# Predict one of the three classes based on a number of variables about what kind of pump is operating, when it was installed, and how it is managed.

# %% [markdown]
# The following set of information about waterpoints is presented for analysis:
# - amount_tsh — Total static head (zero for open tanks and closed circ sys)
# - date_recorded — The date the row was entered
# - funder — Who funded the well
# - gps_height — Altitude of the well
# - installer — Organization that installed the well
# - longitude — GPS coordinate
# - latitude — GPS coordinate
# - wpt_name — Name of the waterpoint if there is one
# - num_private — No information
# - basin — Geographic water basin
# - subvillage — Geographic location
# - region — Geographic location
# - region_code — Geographic location (coded)
# - district_code — Geographic location (coded)
# - lga — Geographic location
# - ward — Geographic location
# - population — Population around the well
# - public_meeting — True/False
# - recorded_by — Group entering this row of data
# - scheme_management — Who operates the waterpoint
# - scheme_name — Who operates the waterpoint
# - permit — If the waterpoint is permitted
# - construction_year — Year the waterpoint was constructed
# - extraction_type — The kind of extraction the waterpoint uses
# - extraction_type_group — The kind of extraction the waterpoint uses
# - extraction_type_class — The kind of extraction the waterpoint uses
# - management — How the waterpoint is managed
# - management_group — How the waterpoint is managed
# - payment — What the water costs
# - payment_type — What the water costs
# - water_quality — The quality of the water
# - quality_group — The quality of the water
# - quantity — The quantity of water
# - quantity_group — The quantity of water (duplicates quality)
# - source — The source of the water
# - source_type — The source of the water
# - source_class — The source of the water
# - waterpoint_type — The kind of waterpoint
# - waterpoint_type_group — The kind of waterpoint

# %%
df_train_set.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... payment_type  \
# 0  34.938093  -9.856322                  none            0  ...     annually
# 1  34.698766  -2.147466              Zahanati            0  ...    never pay
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...   per bucket
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...    never pay
# 4  31.130847  -1.825359               Shuleni            0  ...    never pay
#
#   water_quality quality_group      quantity  quantity_group  \
# 0          soft          good        enough          enough
# 1          soft          good  insufficient    insufficient
# 2          soft          good        enough          enough
# 3          soft          good           dry             dry
# 4          soft          good      seasonal        seasonal
#
#                  source           source_type  source_class  \
# 0                spring                spring   groundwater
# 1  rainwater harvesting  rainwater harvesting       surface
# 2                   dam                   dam       surface
# 3           machine dbh              borehole   groundwater
# 4  rainwater harvesting  rainwater harvesting       surface
#
#                waterpoint_type waterpoint_type_group
# 0           communal standpipe    communal standpipe
# 1           communal standpipe    communal standpipe
# 2  communal standpipe multiple    communal standpipe
# 3  communal standpipe multiple    communal standpipe
# 4           communal standpipe    communal standpipe
#
# [5 rows x 40 columns]

# %%
df_train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   amount_tsh             59400 non-null  float64
#  2   date_recorded          59400 non-null  object
#  3   funder                 55765 non-null  object
#  4   gps_height             59400 non-null  int64
#  5   installer              55745 non-null  object
#  6   longitude              59400 non-null  float64
#  7   latitude               59400 non-null  float64
#  8   wpt_name               59400 non-null  object
#  9   num_private            59400 non-null  int64
#  10  basin                  59400 non-null  object
#  11  subvillage             59029 non-null  object
#  12  region                 59400 non-null  object
#  13  region_code            59400 non-null  int64
#  14  district_code          59400 non-null  int64
#  15  lga                    59400 non-null  object
#  16  ward                   59400 non-null  object
#  17  population             59400 non-null  int64
#  18  public_meeting         56066 non-null  object
#  19  recorded_by            59400 non-null  object
#  20  scheme_management      55523 non-null  object
#  21  scheme_name            31234 non-null  object
#  22  permit                 56344 non-null  object
#  23  construction_year      59400 non-null  int64
#  24  extraction_type        59400 non-null  object
#  25  extraction_type_group  59400 non-null  object
#  26  extraction_type_class  59400 non-null  object
#  27  management             59400 non-null  object
#  28  management_group       59400 non-null  object
#  29  payment                59400 non-null  object
#  30  payment_type           59400 non-null  object
#  31  water_quality          59400 non-null  object
#  32  quality_group          59400 non-null  object
#  33  quantity               59400 non-null  object
#  34  quantity_group         59400 non-null  object
#  35  source                 59400 non-null  object
#  36  source_type            59400 non-null  object
#  37  source_class           59400 non-null  object
#  38  waterpoint_type        59400 non-null  object
#  39  waterpoint_type_group  59400 non-null  object
# dtypes: float64(3), int64(7), object(30)
# memory usage: 18.1+ MB

# %%
df_train_labels['status_group'].value_counts(normalize=True,dropna=False)
# Out:
# functional                 0.543081
# non functional             0.384242
# functional needs repair    0.072677
# Name: status_group, dtype: float64

# %%
df_train_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            59400 non-null  int64
#  1   status_group  59400 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 928.2+ KB

# %%
df_train_labels['status_group'].value_counts(normalize=True)
# Out:
# functional                 0.543081
# non functional             0.384242
# functional needs repair    0.072677
# Name: status_group, dtype: float64

# %% [markdown]
# - Most wells are either functional or non functional, functional needs repair is ~ 7%

# %%
# print top 5 most frequent values in each column
for col in df_train_set.columns:
    print(col, '\n', df_train_set[col].value_counts(normalize=True).head(), '\n\n')
# Out:
# id
#  2047     0.000017
# 72310    0.000017
# 49805    0.000017
# 51852    0.000017
# 62091    0.000017
# Name: id, dtype: float64
#
#
# amount_tsh
#  0.0       0.700993
# 500.0     0.052222
# 50.0      0.041616
# 1000.0    0.025051
# 20.0      0.024630
# Name: amount_tsh, dtype: float64
#
#
# date_recorded
#  2011-03-15    0.009630
# 2011-03-17    0.009394
# 2013-02-03    0.009192
# 2011-03-14    0.008754
# 2011-03-16    0.008636
# Name: date_recorded, dtype: float64
#
#
# funder
#  Government Of Tanzania    0.162898
# Danida                    0.055841
# Hesawa                    0.039487
# Rwssp                     0.024639
# World Bank                0.024191
# Name: funder, dtype: float64
#
#
# gps_height
#   0     0.344074
# -15    0.001010
# -16    0.000926
# -13    0.000926
# -20    0.000875
# Name: gps_height, dtype: float64
#
#
# installer
#  DWE           0.312171
# Government    0.032738
# RWE           0.021634
# Commu         0.019015
# DANIDA        0.018836
# Name: installer, dtype: float64
#
#
# longitude
#  0.000000     0.030505
# 37.540901    0.000034
# 33.010510    0.000034
# 39.093484    0.000034
# 32.972719    0.000034
# Name: longitude, dtype: float64
#
#
# latitude
#  -2.000000e-08    0.030505
# -6.985842e+00    0.000034
# -3.797579e+00    0.000034
# -6.981884e+00    0.000034
# -7.104625e+00    0.000034
# Name: latitude, dtype: float64
#
#
# wpt_name
#  none         0.059983
# Shuleni      0.029428
# Zahanati     0.013973
# Msikitini    0.009007
# Kanisani     0.005438
# Name: wpt_name, dtype: float64
#
#
# num_private
#  0    0.987256
# 6    0.001364
# 1    0.001229
# 5    0.000774
# 8    0.000774
# Name: num_private, dtype: float64
#
#
# basin
#  Lake Victoria      0.172525
# Pangani            0.150505
# Rufiji             0.134276
# Internal           0.131061
# Lake Tanganyika    0.108283
# Name: basin, dtype: float64
#
#
# subvillage
#  Madukani    0.008606
# Shuleni     0.008572
# Majengo     0.008504
# Kati        0.006319
# Mtakuja     0.004438
# Name: subvillage, dtype: float64
#
#
# region
#  Iringa         0.089125
# Shinyanga      0.083872
# Mbeya          0.078098
# Kilimanjaro    0.073721
# Morogoro       0.067441
# Name: region, dtype: float64
#
#
# region_code
#  11    0.089226
# 17    0.084360
# 12    0.078098
# 3     0.073721
# 5     0.068013
# Name: region_code, dtype: float64
#
#
# district_code
#  1    0.205438
# 2    0.188098
# 3    0.168316
# 4    0.151498
# 5    0.073333
# Name: district_code, dtype: float64
#
#
# lga
#  Njombe          0.042138
# Arusha Rural    0.021077
# Moshi Rural     0.021061
# Bariadi         0.019815
# Rungwe          0.018620
# Name: lga, dtype: float64
#
#
# ward
#  Igosi        0.005168
# Imalinyi     0.004242
# Siha Kati    0.003906
# Mdandu       0.003889
# Nduruma      0.003653
# Name: ward, dtype: float64
#
#
# population
#  0      0.359949
# 1      0.118266
# 200    0.032660
# 150    0.031852
# 250    0.028300
# Name: population, dtype: float64
#
#
# public_meeting
#  True     0.909838
# False    0.090162
# Name: public_meeting, dtype: float64
#
#
# recorded_by
#  GeoData Consultants Ltd    1.0
# Name: recorded_by, dtype: float64
#
#
# scheme_management
#  VWC                0.662662
# WUG                0.093763
# Water authority    0.056787
# WUA                0.051924
# Water Board        0.049493
# Name: scheme_management, dtype: float64
#
#
# scheme_name
#  K                0.021835
# None             0.020619
# Borehole         0.017481
# Chalinze wate    0.012967
# M                0.012807
# Name: scheme_name, dtype: float64
#
#
# permit
#  True     0.68955
# False    0.31045
# Name: permit, dtype: float64
#
#
# construction_year
#  0       0.348636
# 2010    0.044529
# 2008    0.043990
# 2009    0.042643
# 2000    0.035202
# Name: construction_year, dtype: float64
#
#
# extraction_type
#  gravity        0.450842
# nira/tanira    0.137273
# other          0.108249
# submersible    0.080202
# swn 80         0.061785
# Name: extraction_type, dtype: float64
#
#
# extraction_type_group
#  gravity        0.450842
# nira/tanira    0.137273
# other          0.108249
# submersible    0.104024
# swn 80         0.061785
# Name: extraction_type_group, dtype: float64
#
#
# extraction_type_class
#  gravity        0.450842
# handpump       0.277037
# other          0.108249
# submersible    0.104024
# motorpump      0.050286
# Name: extraction_type_class, dtype: float64
#
#
# management
#  vwc                 0.681936
# wug                 0.109680
# water board         0.049377
# wua                 0.042677
# private operator    0.033182
# Name: management, dtype: float64
#
#
# management_group
#  user-group    0.883670
# commercial    0.061246
# parastatal    0.029764
# other         0.015875
# unknown       0.009444
# Name: management_group, dtype: float64
#
#
# payment
#  never pay                0.426734
# pay per bucket           0.151263
# pay monthly              0.139731
# unknown                  0.137323
# pay when scheme fails    0.065892
# Name: payment, dtype: float64
#
#
# payment_type
#  never pay     0.426734
# per bucket    0.151263
# monthly       0.139731
# unknown       0.137323
# on failure    0.065892
# Name: payment_type, dtype: float64
#
#
# water_quality
#  soft        0.855522
# salty       0.081751
# unknown     0.031582
# milky       0.013535
# coloured    0.008249
# Name: water_quality, dtype: float64
#
#
# quality_group
#  good       0.855522
# salty      0.087458
# unknown    0.031582
# milky      0.013535
# colored    0.008249
# Name: quality_group, dtype: float64
#
#
# quantity
#  enough          0.558687
# insufficient    0.254697
# dry             0.105152
# seasonal        0.068182
# unknown         0.013283
# Name: quantity, dtype: float64
#
#
# quantity_group
#  enough          0.558687
# insufficient    0.254697
# dry             0.105152
# seasonal        0.068182
# unknown         0.013283
# Name: quantity_group, dtype: float64
#
#
# source
#  spring                  0.286549
# shallow well            0.283232
# machine dbh             0.186448
# river                   0.161818
# rainwater harvesting    0.038636
# Name: source, dtype: float64
#
#
# source_type
#  spring                  0.286549
# shallow well            0.283232
# borehole                0.201162
# river/lake              0.174697
# rainwater harvesting    0.038636
# Name: source_type, dtype: float64
#
#
# source_class
#  groundwater    0.770943
# surface        0.224377
# unknown        0.004680
# Name: source_class, dtype: float64
#
#
# waterpoint_type
#  communal standpipe             0.480168
# hand pump                      0.294411
# other                          0.107407
# communal standpipe multiple    0.102744
# improved spring                0.013199
# Name: waterpoint_type, dtype: float64
#
#
# waterpoint_type_group
#  communal standpipe    0.582912
# hand pump             0.294411
# other                 0.107407
# improved spring       0.013199
# cattle trough         0.001953
# Name: waterpoint_type_group, dtype: float64

# %% [markdown]
# - amount_tsh: majority are zeros (70%)
# - gps_height: top value is zero (34%)
# - longitude: top value is zero (3%) these are not valid as Tanzania does not run through the prime meridian
# - region and region_code: remove region
# - wpt_name: top value is none. (5%)
# - num_private: top value is zero (98%)
# - population: top value is zero (36%)
# - recorded_by: only one value can remove
# - construction_year: top value is zero (34%)
# - extraction_type and extraction_type_field are the same, extraction_type_class looks like a more specific version most likely will only keep this one
# - quality_group looks to be a replacement for water_quality
# - quantity and quantity_group look the same
# - source vs source_type vs source_class: source_class is least specific
# - waterpoint_type vs waterpoint_type_group: waterpoint_type distinguishes multiple and single standpipe

# %%
# Plot of the target status group

plt.hist(df_train_labels['status_group'])
plt.xlabel('status group', fontsize=14)
plt.title("Distribution of Well Status", fontsize=16)
plt.show()

# %% [markdown]
# Here we see a strong class imbalance that will need to be dealt with.

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Missing Values

# %% [markdown]
# ### permit

# %%
df_train_set['permit'].value_counts(normalize=True,dropna=False)
# Out:
# True     0.654074
# False    0.294478
# NaN      0.051448
# Name: permit, dtype: float64

# %%
# df_train_set.subvillage.fillna(0, inplace=True)
df_train_set.permit.fillna(0, inplace=True)
# df_train_set.public_meeting.fillna(0, inplace=True)
# df_train_set.scheme_management.fillna(0, inplace=True)

# %%
df_train_set['permit'].value_counts(normalize=True,dropna=False)
# Out:
# True     0.654074
# False    0.345926
# Name: permit, dtype: float64

# %%
#Make Permit boolean
df_train_set['permit'] = df_train_set['permit'].map(lambda x: 1 if x ==True else 0)
df_train_set['permit'].value_counts(normalize=True)
# Out:
# 1    0.654074
# 0    0.345926
# Name: permit, dtype: float64

# %% [markdown]
# ### construction_year

# %%
# Close to 35% are zero lets replace this with the median year 2000
df_train_set['construction_year'].value_counts(normalize=True,dropna=False)
# Out:
# 0       0.348636
# 2010    0.044529
# 2008    0.043990
# 2009    0.042643
# 2000    0.035202
# 2007    0.026717
# 2006    0.024764
# 2003    0.021650
# 2011    0.021145
# 2004    0.018906
# 2012    0.018249
# 2002    0.018098
# 1978    0.017458
# 1995    0.017071
# 2005    0.017020
# 1999    0.016481
# 1998    0.016263
# 1990    0.016061
# 1985    0.015909
# 1980    0.013653
# 1996    0.013653
# 1984    0.013114
# 1982    0.012525
# 1994    0.012424
# 1972    0.011919
# 1974    0.011380
# 1997    0.010842
# 1992    0.010774
# 1993    0.010236
# 2001    0.009091
# 1988    0.008771
# 1983    0.008215
# 1975    0.007357
# 1986    0.007306
# 1976    0.006970
# 1970    0.006919
# 1991    0.005455
# 1989    0.005320
# 1987    0.005084
# 1981    0.004007
# 1977    0.003401
# 1979    0.003232
# 1973    0.003098
# 2013    0.002963
# 1971    0.002441
# 1960    0.001717
# 1967    0.001481
# 1963    0.001431
# 1968    0.001296
# 1969    0.000993
# 1964    0.000673
# 1962    0.000505
# 1961    0.000354
# 1965    0.000320
# 1966    0.000286
# Name: construction_year, dtype: float64

# %%
# nonzero_median_year = df_train_set[ df_train_set.construction_year != 0 ].median()
# nonzero_median_year[construction_year]

# %%
nonzero_median_year = df_train_set[ df_train_set.construction_year != 0 ].median()

# %%
nonzero_median_year['construction_year'] = nonzero_median_year['construction_year'].astype(int)
nonzero_median_year['construction_year']
# Out:
# 2000.0

# %%
# df_train_set['construction_year'] = df_train_set['construction_year'].replace(to_replace = 0,
#                  value = 2000)

# %%
df_train_set['construction_year'].value_counts(normalize=True,dropna=False)
# Out:
# 0       0.348636
# 2010    0.044529
# 2008    0.043990
# 2009    0.042643
# 2000    0.035202
# 2007    0.026717
# 2006    0.024764
# 2003    0.021650
# 2011    0.021145
# 2004    0.018906
# 2012    0.018249
# 2002    0.018098
# 1978    0.017458
# 1995    0.017071
# 2005    0.017020
# 1999    0.016481
# 1998    0.016263
# 1990    0.016061
# 1985    0.015909
# 1980    0.013653
# 1996    0.013653
# 1984    0.013114
# 1982    0.012525
# 1994    0.012424
# 1972    0.011919
# 1974    0.011380
# 1997    0.010842
# 1992    0.010774
# 1993    0.010236
# 2001    0.009091
# 1988    0.008771
# 1983    0.008215
# 1975    0.007357
# 1986    0.007306
# 1976    0.006970
# 1970    0.006919
# 1991    0.005455
# 1989    0.005320
# 1987    0.005084
# 1981    0.004007
# 1977    0.003401
# 1979    0.003232
# 1973    0.003098
# 2013    0.002963
# 1971    0.002441
# 1960    0.001717
# 1967    0.001481
# 1963    0.001431
# 1968    0.001296
# 1969    0.000993
# 1964    0.000673
# 1962    0.000505
# 1961    0.000354
# 1965    0.000320
# 1966    0.000286
# Name: construction_year, dtype: float64

# %% [markdown]
# ## Replace mispellings and group smaller categories

# %% [markdown]
# ### Reformat Installer col

# %%
df_train_set['installer'] = df_train_set['installer'].astype(str).str.lower()
df_train_set['installer'].replace(to_replace=('0', 'nan', '-'), value='other', inplace=True)

# %%
df_train_set['installer'].value_counts(normalize=True)
# Out:
# dwe             0.293013
# other           0.074663
# government      0.031835
# hesawa          0.023485
# rwe             0.020303
#                   ...
# tcrs a          0.000017
# tz as           0.000017
# rc njoro        0.000017
# ccp             0.000017
# isf / tasaff    0.000017
# Name: installer, Length: 1934, dtype: float64

# %%
df_clean=pd.read_csv('data/lookups.csv')
df_train_set = pd.merge(df_train_set, df_clean, how='left', left_on='installer', right_on='installer_old')
df_train_set.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       grumeti
# 2  34310        25.0    2013-02-25  Lottery Club         686  world vision
# 3  67743         0.0    2013-01-28        Unicef         263        unicef
# 4  19728         0.0    2011-07-13   Action In A           0       artisan
#
#    longitude   latitude              wpt_name  num_private  ... quality_group  \
# 0  34.938093  -9.856322                  none            0  ...          good
# 1  34.698766  -2.147466              Zahanati            0  ...          good
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...          good
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...          good
# 4  31.130847  -1.825359               Shuleni            0  ...          good
#
#        quantity quantity_group                source           source_type  \
# 0        enough         enough                spring                spring
# 1  insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 2        enough         enough                   dam                   dam
# 3           dry            dry           machine dbh              borehole
# 4      seasonal       seasonal  rainwater harvesting  rainwater harvesting
#
#   source_class              waterpoint_type  waterpoint_type_group  \
# 0  groundwater           communal standpipe     communal standpipe
# 1      surface           communal standpipe     communal standpipe
# 2      surface  communal standpipe multiple     communal standpipe
# 3  groundwater  communal standpipe multiple     communal standpipe
# 4      surface           communal standpipe     communal standpipe
#
#   installer_old installer_new
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN
#
# [5 rows x 42 columns]

# %%
df_train_set['installer_new'].isna().sum()
# Out:
# 44958

# %%
df_train_set['installer'].value_counts(normalize=True)
# Out:
# dwe             0.293013
# other           0.074663
# government      0.031835
# hesawa          0.023485
# rwe             0.020303
#                   ...
# tcrs a          0.000017
# tz as           0.000017
# rc njoro        0.000017
# ccp             0.000017
# isf / tasaff    0.000017
# Name: installer, Length: 1934, dtype: float64

# %%
df_train_set['installer_new'].fillna(df_train_set['installer'], inplace=True)

df_train_set
# Out:
#           id  amount_tsh date_recorded           funder  gps_height  \
# 0      69572      6000.0    2011-03-14            Roman        1390
# 1       8776         0.0    2013-03-06          Grumeti        1399
# 2      34310        25.0    2013-02-25     Lottery Club         686
# 3      67743         0.0    2013-01-28           Unicef         263
# 4      19728         0.0    2011-07-13      Action In A           0
# ...      ...         ...           ...              ...         ...
# 59395  60739        10.0    2013-05-03  Germany Republi        1210
# 59396  27263      4700.0    2011-05-07      Cefa-njombe        1212
# 59397  37057         0.0    2011-04-11              NaN           0
# 59398  31282         0.0    2011-03-08            Malec           0
# 59399  26348         0.0    2011-03-23       World Bank         191
#
#           installer  longitude   latitude              wpt_name  num_private  \
# 0             roman  34.938093  -9.856322                  none            0
# 1           grumeti  34.698766  -2.147466              Zahanati            0
# 2      world vision  37.460664  -3.821329           Kwa Mahundi            0
# 3            unicef  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4           artisan  31.130847  -1.825359               Shuleni            0
# ...             ...        ...        ...                   ...          ...
# 59395           ces  37.169807  -3.253847   Area Three Namba 27            0
# 59396          cefa  35.249991  -9.070629     Kwa Yahona Kuvala            0
# 59397         other  34.017087  -8.750434               Mashine            0
# 59398          musa  35.861315  -6.378573                Mshoro            0
# 59399         world  38.104048  -6.747464       Kwa Mzee Lugawa            0
#
#        ... quality_group      quantity quantity_group                source  \
# 0      ...          good        enough         enough                spring
# 1      ...          good  insufficient   insufficient  rainwater harvesting
# 2      ...          good        enough         enough                   dam
# 3      ...          good           dry            dry           machine dbh
# 4      ...          good      seasonal       seasonal  rainwater harvesting
# ...    ...           ...           ...            ...                   ...
# 59395  ...          good        enough         enough                spring
# 59396  ...          good        enough         enough                 river
# 59397  ...      fluoride        enough         enough           machine dbh
# 59398  ...          good  insufficient   insufficient          shallow well
# 59399  ...         salty        enough         enough          shallow well
#
#                 source_type source_class              waterpoint_type  \
# 0                    spring  groundwater           communal standpipe
# 1      rainwater harvesting      surface           communal standpipe
# 2                       dam      surface  communal standpipe multiple
# 3                  borehole  groundwater  communal standpipe multiple
# 4      rainwater harvesting      surface           communal standpipe
# ...                     ...          ...                          ...
# 59395                spring  groundwater           communal standpipe
# 59396            river/lake      surface           communal standpipe
# 59397              borehole  groundwater                    hand pump
# 59398          shallow well  groundwater                    hand pump
# 59399          shallow well  groundwater                    hand pump
#
#        waterpoint_type_group installer_old installer_new
# 0         communal standpipe           NaN         roman
# 1         communal standpipe           NaN       grumeti
# 2         communal standpipe           NaN  world vision
# 3         communal standpipe           NaN        unicef
# 4         communal standpipe           NaN       artisan
# ...                      ...           ...           ...
# 59395     communal standpipe           NaN           ces
# 59396     communal standpipe           NaN          cefa
# 59397              hand pump         other         other
# 59398              hand pump           NaN          musa
# 59399              hand pump           NaN         world
#
# [59400 rows x 42 columns]

# %%
df_train_set['installer_new'].isna().sum()
# Out:
# 0

# %%
df_train_set['installer_new'].value_counts(normalize=True)
# Out:
# dwe                     0.304983
# other                   0.074663
# tanzanian government    0.062323
# community               0.033266
# danida                  0.028300
#                           ...
# kwasenenge group        0.000017
# omary mona              0.000017
# mkon construction       0.000017
# balyeh                  0.000017
# m                       0.000017
# Name: installer_new, Length: 1652, dtype: float64

# %%
del df_train_set['installer']
del df_train_set['installer_old']

# %%
df_installer_cnt = df_train_set['installer_new'].value_counts(normalize=True)
df_installer_cnt
# Out:
# dwe                     0.304983
# other                   0.074663
# tanzanian government    0.062323
# community               0.033266
# danida                  0.028300
#                           ...
# kwasenenge group        0.000017
# omary mona              0.000017
# mkon construction       0.000017
# balyeh                  0.000017
# m                       0.000017
# Name: installer_new, Length: 1652, dtype: float64

# %%
df_installer_cnt.head(20)
# Out:
# dwe                     0.304983
# other                   0.074663
# tanzanian government    0.062323
# community               0.033266
# danida                  0.028300
# hesawa                  0.023620
# council                 0.022929
# rwe                     0.020303
# church                  0.016330
# kkkt                    0.015623
# finw                    0.013199
# tcrs                    0.012458
# world vision            0.012037
# ces                     0.010269
# amref                   0.007458
# lga                     0.006953
# tasaf                   0.006919
# wedeco                  0.006700
# dmdd                    0.006330
# norad                   0.006162
# Name: installer_new, dtype: float64

# %%
other_list = df_installer_cnt[df_installer_cnt<.01].index.tolist()
other_list
# Out:
# ['amref',
#  'lga',
#  'tasaf',
#  'wedeco',
#  'dmdd',
#  'norad',
#  'unicef',
#  'twesa',
#  'da',
#  'wu',
#  'acra',
#  'sema',
#  'jaica',
#  'oxfam',
#  'shipo',
#  'local',
#  'idara ya maji',
#  'villagers',
#  'sengerema water department',
#  'kiliwater',
#  'dh',
#  'kuwait',
#  'distri',
#  'lawatefuka water sup',
#  'magadini-makiwaru wa',
#  'fw',
#  'private',
#  'centr',
#  'wvt',
#  'mwe',
#  'handeni trunk main(',
#  'is',
#  'world bank',
#  'water aid',
#  'wananchi',
#  'rwssp',
#  'jica',
#  'isf',
#  'adra',
#  'artisan',
#  'ddca',
#  'he',
#  'world',
#  'african group',
#  'tardo',
#  'ir',
#  'consulting engineer',
#  'twe',
#  'muwsa',
#  'ded',
#  'wizara ya maji',
#  'halmashauri ya wilaya sikonge',
#  'hsw',
#  'go',
#  'angli',
#  'ki',
#  'oxfarm',
#  'roman',
#  'vwc',
#  'cefa',
#  'h',
#  'aict',
#  'mdrdp',
#  'water board',
#  'region water department',
#  'chamavita',
#  'water',
#  'lwi',
#  'wa',
#  'gtz',
#  'villa',
#  'dawasco',
#  'mtn',
#  'tassaf',
#  'ncaa',
#  'losaa-kia water supp',
#  'wachina',
#  'lvia',
#  'wanan',
#  'gen',
#  'co',
#  'rdc',
#  'tlc',
#  'priva',
#  'st',
#  'dhv',
#  'pr',
#  'cdtf',
#  'water aid /sema',
#  'islamic group',
#  'ka',
#  'miziriol',
#  'mlade',
#  'plan internationa',
#  'solidame',
#  'shawasa',
#  'tdft',
#  'red cross',
#  'ga',
#  'jandu plumber co',
#  'not known',
#  'cbhcc',
#  'concern',
#  'mwe &',
#  'grumeti',
#  'kili water',
#  'kuwasa',
#  'shy builders',
#  'do',
#  'jbg',
#  'tanapa',
#  'kidp',
#  'mbiuwasa',
#  'bsf',
#  'ch',
#  'hapa singida',
#  'msabi',
#  'muwasa',
#  'kkt',
#  'padep',
#  'si',
#  'ma',
#  'kiuma',
#  'vtecos',
#  'tuwasa',
#  'holland',
#  'cjejow',
#  'wateraid',
#  'cons',
#  'the desk and chair foundat',
#  'kalta',
#  'happy watoto foundation',
#  'wb',
#  'kaemp',
#  'kokeni',
#  'accra',
#  'po',
#  'ccec',
#  'marafip',
#  'swiss if',
#  'abasia',
#  'af',
#  'gwasco l',
#  'water aid/sema',
#  'rhobi',
#  'ereto',
#  'cocane',
#  'un',
#  'active mkm',
#  'individuals',
#  'wd and id',
#  'besada',
#  'jika',
#  'mi',
#  'total land care',
#  'tawasa',
#  'hans',
#  'ifad',
#  'tan plant ltd',
#  'juin co',
#  'ics',
#  'kilwater',
#  'serikali',
#  'mileniam project',
#  'cmsr',
#  'wo',
#  'geotan',
#  'ridep',
#  'pet',
#  'kalitasi',
#  'tredep',
#  'nyakilangani co',
#  'kyasha enterpr',
#  'vifafi',
#  'ce',
#  'wwf',
#  'mtuwasa',
#  'halmashauri',
#  'korogwe water works',
#  'ta',
#  'ilct',
#  'care international',
#  'cosmo',
#  'sabodo',
#  'udc/sema',
#  'fathe',
#  'chinese group',
#  'hydrotec',
#  'nora',
#  'singida yetu',
#  'save the rain usa',
#  'consuting engineer',
#  'bgm',
#  'w/',
#  'jicks',
#  'maswi company',
#  'kadp',
#  'makonde water population',
#  'orien',
#  'kim kim construction',
#  'p',
#  'kuamu',
#  'adp',
#  'cg',
#  'plan int',
#  'sowasa',
#  'idydc',
#  'rotary club',
#  'jandu plumber  co',
#  'efg',
#  'maji mugumu',
#  'tanz',
#  'dads',
#  'mkuyu',
#  'mbunge',
#  'citizen engine',
#  'sumbaw',
#  'naishu construction co. ltd',
#  'tasaf/dmdd',
#  'quwkwin',
#  'chur',
#  'ukilig',
#  'sda',
#  'ruthe',
#  'bruder',
#  'finland government',
#  'shule',
#  'livi',
#  'wfp',
#  'msf',
#  'the i',
#  'grobal resource alliance',
#  'us embassy',
#  'tahea',
#  'ja',
#  'mackd',
#  'regional water',
#  'tpp trustmoshi',
#  'maswi',
#  'adp busangi',
#  'fpct',
#  'pet corporation ltd',
#  'rw',
#  'mw',
#  'konoike',
#  'ad',
#  'villag',
#  'nandra construction',
#  'living water international',
#  'ministry of water',
#  'sia ltd',
#  'sao',
#  'canop',
#  'saxon',
#  'wsdp',
#  'kiliflora',
#  'phase',
#  'isf/tacare',
#  'qwickwin',
#  'mpang',
#  'msf/tacare',
#  'inter',
#  'mviwa',
#  'would bank',
#  'rwsp',
#  'water project mbawala chini',
#  'mamad',
#  'benguka',
#  'mosque',
#  'jeica',
#  'daldo',
#  'msikiti',
#  'unhcr',
#  'goldstar',
#  'secondary',
#  'canada na tanzania',
#  'halmashauri ya manispa tabora',
#  'cosmos engineering',
#  'vill',
#  'consultant',
#  'w',
#  'ham',
#  'prf',
#  'conce',
#  'dak',
#  'ml appro',
#  'pidp',
#  'ai',
#  'ardhi water well',
#  'consultant engineer',
#  'karugendo',
#  'exaud msambwa',
#  'songas',
#  'hapa',
#  'kwikwiz',
#  'gwaseco',
#  'auwasa',
#  'idea',
#  'kmcl',
#  'd',
#  'songa',
#  'sijm',
#  'nice',
#  'japan',
#  'suleman idd',
#  'mamlaka ya maji ngara',
#  'lamp',
#  'gain',
#  'redep',
#  'atigh buildings',
#  'serikali ya kijiji',
#  'rips',
#  'suwasa',
#  'water  aid',
#  'rudep/',
#  'aic',
#  'tag',
#  'milenia',
#  'ministry of water engineer',
#  'no',
#  'kalumbwa',
#  'idara',
#  'ikela wa',
#  'ubalozi wa marekani',
#  'dr. matomola',
#  'rudep',
#  'active tank co',
#  'european union',
#  'singida general  supplies  ltd',
#  'aimgold',
#  'kilwa company',
#  'amp contractor',
#  'ubung',
#  'regional water engineer arusha',
#  'action contre la faim',
#  'victoria',
#  'mzinga a',
#  'roman catholic',
#  'cartas',
#  'kalago enterprises co.ltd',
#  'healt',
#  'cct',
#  'roman catholic rulenge diocese',
#  'williamson diamond ltd',
#  'germany',
#  'pci',
#  'mdala contractor',
#  'duwas',
#  'redeso',
#  'i.e.c',
#  'br',
#  'wua',
#  'bulyahunlu gold mine',
#  'village',
#  'angrikana',
#  'moroil',
#  'pit cooperation  ltd',
#  'roman cathoric -kilomeni',
#  'belgiam government',
#  'contr',
#  'tltc',
#  'rhoda',
#  'institution',
#  'baric',
#  'lawate fuka water su',
#  'saxon building contractor',
#  'simba co',
#  'mianz',
#  'lva ltd',
#  'mws',
#  'mlaki co',
#  'el',
#  'cosmos eng ltd',
#  'mileniam',
#  'dct',
#  'makonde',
#  'rundu man',
#  'save the rain',
#  'sema co ltd',
#  'mack donald contractor',
#  'kta c',
#  'sauwasa',
#  'ms',
#  'kanisa',
#  'kigoma municipal',
#  'rude',
#  're',
#  'manyara construction',
#  'amp contract',
#  'dardo',
#  'wedeco/wessons',
#  'mzungu paul',
#  'nanra contractor',
#  'total landcare',
#  'mida',
#  'scott',
#  'mboma',
#  'lench',
#  'clause workers',
#  'yumbaka engineering',
#  'muslims',
#  'shuwasa',
#  'kimkum',
#  'wanjoda',
#  'amp contracts',
#  'maji block',
#  'sanje wa',
#  'dasip',
#  'villager',
#  'secondary school',
#  'trachoma',
#  'w.c.s',
#  'kashwa',
#  'tasaf/',
#  'st ph',
#  'ea',
#  'pata',
#  'amboni plantation',
#  'cpro',
#  'tanzania',
#  'gida contractor',
#  'plan international',
#  'idc',
#  'rished',
#  'adb',
#  'atlas company',
#  'victoria drill co',
#  'british government',
#  'elct',
#  'kirdep',
#  'trust',
#  'tulawaka gold mine',
#  'tridep',
#  'obc',
#  'masjid',
#  'maswi drill',
#  'linda',
#  'gold star',
#  'biore',
#  'gaica',
#  'bffs',
#  'kkt c',
#  'desk c',
#  't. n. karugendo',
#  'mombo urban water s',
#  'rundaga',
#  'kanisa katoliki',
#  'we',
#  'greec',
#  'tumaini fund',
#  'victoria company',
#  'musa',
#  'kinapa',
#  'mgm',
#  'tabraki',
#  'chiko',
#  'jeshi la wokovu',
#  'dbspe',
#  'tanap',
#  'makama construction',
#  'water  aid/sema',
#  'wasso',
#  'runduman',
#  'bilila',
#  'cspd',
#  'mem',
#  'wasso companies',
#  'zacharia mtn',
#  'totoland care',
#  'people p',
#  'unknown',
#  'maji tech construction',
#  'ministryof water',
#  'irevea sister',
#  'vttp',
#  'tanzakesho',
#  'maendeleo ya jamii',
#  'serengeti district concil',
#  'tgts',
#  'maji tech',
#  'school',
#  'australia',
#  'msikit',
#  'koica',
#  'rural water supply',
#  'grumeti singita',
#  'cartas tanzania',
#  'makonde water supply',
#  'concen',
#  'ruangwa contractor',
#  'ola',
#  'bridge north',
#  'diocese of geita',
#  'saleh zaharani',
#  'dr. matobola',
#  'geochaina',
#  'kowi',
#  't',
#  'losa-kia water suppl',
#  'juin',
#  'adap',
#  'caltas',
#  'marti',
#  'uhai wa mama na mtoto',
#  'umoja drilling',
#  'dee',
#  'kk',
#  'longido sec school',
#  'in',
#  'efam',
#  'aar',
#  'roman ca',
#  'r.c',
#  'mwanga town water authority',
#  'howard and humfrey consultant',
#  'w.d &',
#  'patuu',
#  'individual',
#  'water department',
#  'nyamongo gold mining',
#  'quick win project',
#  'atisan',
#  'jlh co ltd',
#  'hiap',
#  'loliondo parish',
#  'magadini makiwaru wa',
#  'un one',
#  'world banks',
#  'cast',
#  'issac mollel',
#  'caltus',
#  'oldonyolengai',
#  'tanas',
#  'tanesco',
#  'uyoge',
#  'lindala co',
#  'word bank',
#  'ha',
#  'bobby',
#  'oikos',
#  'cipro/care',
#  'mchuk',
#  'ifakara',
#  'nduku village',
#  'gachuma ginery',
#  'mchome',
#  'singasinga',
#  'mombo urban water',
#  'tanz egypt technical coopera',
#  'quik',
#  'greinaker',
#  'ardhi instute',
#  'yebe chikomesh',
#  'f',
#  'part',
#  'diwani',
#  'halmashauri ya wilaya',
#  'inves',
#  'plan tanzania',
#  'buguba',
#  'ns',
#  'ustawi',
#  'rural',
#  'stampers',
#  'wasso contractors',
#  'hospi',
#  'victoria drill',
#  'kerebuka',
#  'zao water spring',
#  "lion's",
#  'vi',
#  'presadom',
#  'rotte',
#  'dhinu',
#  'l',
#  'sw',
#  'belgij',
#  'simavi',
#  'milenium',
#  'enyueti',
#  'mazi investment',
#  'sida',
#  'cheni',
#  'ng',
#  'nassor fehed',
#  'kaluwike',
#  'rombo dalta',
#  'halmashauli',
#  'sacso',
#  'italy government',
#  'wvc',
#  'u.s.a',
#  'cobashec',
#  'tpp',
#  'pad',
#  'kaembe',
#  'hindu',
#  'halmashauri/quick win project',
#  'make engineering',
#  'mwaki contractor',
#  'indi',
#  'building works company ltd',
#  'lgcdg',
#  'dbfpe',
#  'maswi drilling',
#  'geita goldmain',
#  'ungan',
#  'selous g',
#  'minjingu',
#  'ruvuma basin',
#  'floresta',
#  'mh kapuya',
#  'tanroad',
#  'gra',
#  'rural drinking water supply',
#  'kyasha entrepr',
#  'koberg contractor',
#  'acord',
#  'nyakilangani construction',
#  'eliza',
#  'dr.matobola',
#  'halmashauri ya mburu',
#  'japan embassy',
#  'furahia trading',
#  'miomb',
#  'kmt',
#  'caritas',
#  'engin',
#  'water hu',
#  'dsv',
#  'mlaki  co',
#  'judge mchome',
#  'dassip',
#  'bokera w',
#  'action aid',
#  'villaers',
#  'aqal',
#  'juma maro',
#  'cipro',
#  'gwitembe',
#  'md',
#  'ar',
#  'kill water',
#  'aquarman drillers',
#  'chani',
#  'gurumeti sagita co',
#  'selikali',
#  'compa',
#  'adam',
#  'tlc/john majala',
#  'nampapanga',
#  'foreigne',
#  'gwasco',
#  'regwa company of egpty',
#  'stansilaus',
#  'gurumeti sagita',
#  'desk and chair foundation',
#  'kijiji',
#  'muham',
#  'umoja drilling construction',
#  'water users group',
#  'hdv',
#  'martha emanuel',
#  'regwa company',
#  'denish',
#  'chacha',
#  'roma',
#  'senapa',
#  'apm',
#  'korea',
#  'active tank co ltd',
#  'henure dema',
#  'calvary connection',
#  'rotar',
#  'nirad',
#  'fptc',
#  'vien construction',
#  'rssp',
#  'p.n.r.',
#  'maro',
#  'india',
#  'makuru',
#  'vw',
#  'faudh tamimu',
#  'regwa company of egypt',
#  'iran govern',
#  'tom',
#  'liuwassa',
#  'undp',
#  'totoland',
#  "tag patmo's",
#  'ddca co',
#  'vitecos',
#  'eno',
#  'nddp',
#  'n.p.r.',
#  'edward',
#  'mbwambo',
#  'redap',
#  'aqua wel',
#  'kilomber',
#  'k',
#  's',
#  'tasa',
#  'tempo',
#  'elias mahemba',
#  'wadeco',
#  'cip',
#  'halmashauri wilaya',
#  'kilolo star',
#  'mwita muremi',
#  'nsc',
#  'george',
#  'cultus',
#  'jhl co ltd',
#  'winnin spirit co ltd',
#  'mdrd_',
#  'municipal',
#  'serena',
#  'q-sem ltd',
#  'ccps',
#  'lips',
#  'folac',
#  'soliderm',
#  'mzung',
#  'christian outrich',
#  'asdp',
#  'nyakilangani',
#  'vickfi',
#  'schoo',
#  'hpa',
#  'jawabu',
#  'msiki',
#  'greineker',
#  'egypt government',
#  'green',
#  'nchagwa',
#  'amec',
#  'mmg gold mine',
#  'w.d. and i.d.',
#  'townsh',
#  'doddea',
#  'machibya',
#  'hospital',
#  'itali',
#  'iado',
#  'laramatak',
#  'pmo',
#  'dadp',
#  'nampopanga',
#  'sua',
#  'karumba building company ltd',
#  'ilolangulu water supply',
#  'dmk',
#  'ship',
#  'kibo',
#  'water authority',
#  'wajerumani',
#  'mp',
#  'north',
#  'ac',
#  'roman cathoric -same',
#  'universal construction',
#  'railway',
#  'coek',
#  'hanja lt',
#  'resolute',
#  'vicfish ltd',
#  'tanganyika basin',
#  'mbuli co',
#  'esawa',
#  'finland',
#  'mwigicho',
#  'dasp',
#  'dcca',
#  'ko',
#  "lion's club",
#  'athumani  janguo',
#  'ddp',
#  'ministry of education',
#  'kyariga',
#  'efarm',
#  'onesm',
#  'anglican',
#  'de',
#  'desk a',
#  'yell ltd',
#  'anglican uganda',
#  'mataro',
#  'maswi co',
#  'bingo foundation',
#  'wedeko',
#  'mtc',
#  'w.b',
#  'kata',
#  'niger',
#  'winnin spirit co',
#  'tbl',
#  'tlc/nyengesa masanja',
#  'ester ndege',
#  'vifaf',
#  'hussein ayubu',
#  'mamaz',
#  'aqua blues angels',
#  'wbk',
#  'dokta mwandulami',
#  "okong'o",
#  'great lakes',
#  'priv',
#  'mohamed ally',
#  'indiv',
#  'shule ya sekondari ipuli',
#  'recoda',
#  'dmdd/solider',
#  'japan government',
#  'engineers without border',
#  'jumanne',
#  'resolute mining',
#  'company',
#  'mohamad masanga',
#  'mbozi hospital',
#  'muhindi',
#  'tz as',
#  'mketo',
#  'mamvua kakungu',
#  'arrian',
#  'mombo urban  water',
#  'subvillage',
#  'sent tho',
#  'sunamco',
#  'friend from un',
#  'lomoloki',
#  'luke samaras ltd',
#  'gdp',
#  'eco lodge',
#  'twess',
#  'sa',
#  'mwita lucas',
#  'mwita kichere',
#  'dar es salaam technician',
#  'mwalimu  muhenza',
#  'jafary mbaga',
#  'st gasper',
#  'fida',
#  'washima',
#  'frida mokeki',
#  'kinga',
#  'babtest',
#  'perusi bhoke',
#  'abd',
#  'namungo',
#  'halmashauri ya manispa  tabora',
#  'ro',
#  'ardhi water wells',
#  'seff mtambo',
#  'tlc/jenus malecha',
#  'coyi',
#  'stephano paulo',
#  'al ha',
#  'taees',
#  'wizara',
#  'msigwa',
#  'hasnein murij',
#  'bonite bottles ltd',
#  'petro patrice',
#  'villigers',
#  'wamba',
#  'mtui',
#  'jumanne siabo',
#  'seronera',
#  'vitecos invest',
#  'lusajo',
#  'goldwill  foundation',
#  'german',
#  'safari roya',
#  'others',
#  'magani',
#  'grobal resource  alliance',
#  'meco',
#  "rashid seng'ombe",
#  'boni',
#  'robert mosi',
#  'maivaru',
#  'mwl. nyerere sec. school',
#  'samweli',
#  'wama',
#  'tasaf and lga',
#  'marijan ally dadi',
#  'kilangani co',
#  'rwi',
#  'italian government',
#  'aixos',
#  'coew',
#  'justine marwa',
#  'lizad',
#  'ji',
#  'shule ya msingi',
#  'ox',
#  'mack donald co ltd',
#  'waheke',
#  'maj mugumu',
#  'loocip',
#  'c',
#  'taipo',
#  'emayo',
#  'john skwese',
#  'kando',
#  'cristan outrich',
#  'engarasero villagers',
#  'pump entecostal sweeden',
#  'mzee omari',
#  'msukwa construction company',
#  'busoga trust',
#  'makoye',
#  'wus',
#  'ddsa',
#  'ramadhani nyambizi',
#  'morrovian',
#  'kitukuni water supply',
#  'elius chacha',
#  'hamisi fidia',
#  'e eto',
#  'korkonel',
#  'moses',
#  'meru concrete',
#  'dhv moro',
#  'mama kapwapwa',
#  'morovi',
#  'karumba biuldin',
#  'jackson mahambo',
#  'naishu construction co.ltd',
#  'lindi rural water department',
#  'chonja charles',
#  'lungwe',
#  'care  international',
#  'grumeti fund',
#  'george mtoto',
#  'g.d&i.d',
#  'masese',
#  'matyenye',
#  'prof. saluati',
#  'zinduka',
#  'insititutiona',
#  'pwd',
#  'teresa munyama',
#  'mgaya',
#  'jwtz',
#  'sipdo',
#  'joery magabe',
#  'maswi drilling co. ltd',
#  'hotel and lodge tanzania',
#  'raramataki',
#  'nssf',
#  'agrican',
#  'matogoro',
#  'lindi contractor',
#  'ols',
#  'enyuati',
#  'siza mayengo',
#  'got',
#  'caltaz kahama',
#  'dsp',
#  'aqua wat',
#  'dydrotec',
#  'shallow well',
#  'lei',
#  'alex moyela',
#  'care/cipro',
#  'sagaswe',
#  'kayempu ltd',
#  'maliasili',
#  'mama hamisa',
#  'simba lodge',
#  'masai land',
#  'noshad',
#  'nyitamboka',
#  'sema consultant',
#  'twende pamoja',
#  'raymond ekura',
#  'hashi',
#  'mark',
#  'kalitesi',
#  'ndrdp',
#  'oda',
#  'sweeden',
#  'peter',
#  'claver',
#  'ccpk',
#  'zuber mihungo',
#  'mbusi mwita',
#  'christina magoge',
#  'o',
#  'institutional',
#  'nyanza road',
#  'primo',
#  'chama cha ushirika',
#  'nassan workers',
#  'tanzania egypt technical co op',
#  'not kno',
#  'cgi',
#  ...]

# %%
df_train_set['installer_new'].replace(to_replace=other_list, value='other', inplace=True)
df_train_set['installer_new'].value_counts(normalize=True)
# Out:
# other                   0.424360
# dwe                     0.304983
# tanzanian government    0.062323
# community               0.033266
# danida                  0.028300
# hesawa                  0.023620
# council                 0.022929
# rwe                     0.020303
# church                  0.016330
# kkkt                    0.015623
# finw                    0.013199
# tcrs                    0.012458
# world vision            0.012037
# ces                     0.010269
# Name: installer_new, dtype: float64

# %%
df_train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   amount_tsh             59400 non-null  float64
#  2   date_recorded          59400 non-null  object
#  3   funder                 55765 non-null  object
#  4   gps_height             59400 non-null  int64
#  5   longitude              59400 non-null  float64
#  6   latitude               59400 non-null  float64
#  7   wpt_name               59400 non-null  object
#  8   num_private            59400 non-null  int64
#  9   basin                  59400 non-null  object
#  10  subvillage             59029 non-null  object
#  11  region                 59400 non-null  object
#  12  region_code            59400 non-null  int64
#  13  district_code          59400 non-null  int64
#  14  lga                    59400 non-null  object
#  15  ward                   59400 non-null  object
#  16  population             59400 non-null  int64
#  17  public_meeting         56066 non-null  object
#  18  recorded_by            59400 non-null  object
#  19  scheme_management      55523 non-null  object
#  20  scheme_name            31234 non-null  object
#  21  permit                 59400 non-null  int64
#  22  construction_year      59400 non-null  int64
#  23  extraction_type        59400 non-null  object
#  24  extraction_type_group  59400 non-null  object
#  25  extraction_type_class  59400 non-null  object
#  26  management             59400 non-null  object
#  27  management_group       59400 non-null  object
#  28  payment                59400 non-null  object
#  29  payment_type           59400 non-null  object
#  30  water_quality          59400 non-null  object
#  31  quality_group          59400 non-null  object
#  32  quantity               59400 non-null  object
#  33  quantity_group         59400 non-null  object
#  34  source                 59400 non-null  object
#  35  source_type            59400 non-null  object
#  36  source_class           59400 non-null  object
#  37  waterpoint_type        59400 non-null  object
#  38  waterpoint_type_group  59400 non-null  object
#  39  installer_new          59400 non-null  object
# dtypes: float64(3), int64(8), object(29)
# memory usage: 18.6+ MB

# %% [markdown]
# ### Reformat Funder col

# %%
df_train_set['funder'] = df_train_set['funder'].astype(str).str.lower()
df_train_set['funder'].replace(to_replace=('0', 'nan', '-'), value='other', inplace=True)

# %%
df_train_set['funder'].value_counts(normalize=True)
# Out:
# government of tanzania    0.152929
# other                     0.074276
# danida                    0.052424
# hesawa                    0.037071
# rwssp                     0.023131
#                             ...
# muhochi kissaka           0.000017
# dagida                    0.000017
# males                     0.000017
# cpps mission              0.000017
# m                         0.000017
# Name: funder, Length: 1897, dtype: float64

# %%
df_clean_funder=pd.read_csv('data/lookups_funder.csv')
df_train_set = pd.merge(df_train_set, df_clean_funder, how='left', left_on='funder', right_on='funder_old')
df_train_set.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height  longitude  \
# 0  69572      6000.0    2011-03-14         roman        1390  34.938093
# 1   8776         0.0    2013-03-06       grumeti        1399  34.698766
# 2  34310        25.0    2013-02-25  lottery club         686  37.460664
# 3  67743         0.0    2013-01-28        unicef         263  38.486161
# 4  19728         0.0    2011-07-13   action in a           0  31.130847
#
#     latitude              wpt_name  num_private                    basin  ...  \
# 0  -9.856322                  none            0               Lake Nyasa  ...
# 1  -2.147466              Zahanati            0            Lake Victoria  ...
# 2  -3.821329           Kwa Mahundi            0                  Pangani  ...
# 3 -11.155298  Zahanati Ya Nanyumbu            0  Ruvuma / Southern Coast  ...
# 4  -1.825359               Shuleni            0            Lake Victoria  ...
#
#        quantity quantity_group                source           source_type  \
# 0        enough         enough                spring                spring
# 1  insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 2        enough         enough                   dam                   dam
# 3           dry            dry           machine dbh              borehole
# 4      seasonal       seasonal  rainwater harvesting  rainwater harvesting
#
#   source_class              waterpoint_type  waterpoint_type_group  \
# 0  groundwater           communal standpipe     communal standpipe
# 1      surface           communal standpipe     communal standpipe
# 2      surface  communal standpipe multiple     communal standpipe
# 3  groundwater  communal standpipe multiple     communal standpipe
# 4      surface           communal standpipe     communal standpipe
#
#   installer_new funder_old funder_new
# 0         other        NaN        NaN
# 1         other        NaN        NaN
# 2  world vision        NaN        NaN
# 3         other        NaN        NaN
# 4         other        NaN        NaN
#
# [5 rows x 42 columns]

# %%
df_train_set['funder_new'].isna().sum()
# Out:
# 39498

# %%
df_train_set['funder'].value_counts(normalize=True)
# Out:
# government of tanzania    0.152929
# other                     0.074276
# danida                    0.052424
# hesawa                    0.037071
# rwssp                     0.023131
#                             ...
# muhochi kissaka           0.000017
# dagida                    0.000017
# males                     0.000017
# cpps mission              0.000017
# m                         0.000017
# Name: funder, Length: 1897, dtype: float64

# %%
df_train_set['funder_new'].fillna(df_train_set['funder'], inplace=True)

df_train_set
# Out:
#           id  amount_tsh date_recorded           funder  gps_height  \
# 0      69572      6000.0    2011-03-14            roman        1390
# 1       8776         0.0    2013-03-06          grumeti        1399
# 2      34310        25.0    2013-02-25     lottery club         686
# 3      67743         0.0    2013-01-28           unicef         263
# 4      19728         0.0    2011-07-13      action in a           0
# ...      ...         ...           ...              ...         ...
# 59395  60739        10.0    2013-05-03  germany republi        1210
# 59396  27263      4700.0    2011-05-07      cefa-njombe        1212
# 59397  37057         0.0    2011-04-11            other           0
# 59398  31282         0.0    2011-03-08            malec           0
# 59399  26348         0.0    2011-03-23       world bank         191
#
#        longitude   latitude              wpt_name  num_private  \
# 0      34.938093  -9.856322                  none            0
# 1      34.698766  -2.147466              Zahanati            0
# 2      37.460664  -3.821329           Kwa Mahundi            0
# 3      38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4      31.130847  -1.825359               Shuleni            0
# ...          ...        ...                   ...          ...
# 59395  37.169807  -3.253847   Area Three Namba 27            0
# 59396  35.249991  -9.070629     Kwa Yahona Kuvala            0
# 59397  34.017087  -8.750434               Mashine            0
# 59398  35.861315  -6.378573                Mshoro            0
# 59399  38.104048  -6.747464       Kwa Mzee Lugawa            0
#
#                          basin  ...      quantity quantity_group  \
# 0                   Lake Nyasa  ...        enough         enough
# 1                Lake Victoria  ...  insufficient   insufficient
# 2                      Pangani  ...        enough         enough
# 3      Ruvuma / Southern Coast  ...           dry            dry
# 4                Lake Victoria  ...      seasonal       seasonal
# ...                        ...  ...           ...            ...
# 59395                  Pangani  ...        enough         enough
# 59396                   Rufiji  ...        enough         enough
# 59397                   Rufiji  ...        enough         enough
# 59398                   Rufiji  ...  insufficient   insufficient
# 59399              Wami / Ruvu  ...        enough         enough
#
#                      source           source_type source_class  \
# 0                    spring                spring  groundwater
# 1      rainwater harvesting  rainwater harvesting      surface
# 2                       dam                   dam      surface
# 3               machine dbh              borehole  groundwater
# 4      rainwater harvesting  rainwater harvesting      surface
# ...                     ...                   ...          ...
# 59395                spring                spring  groundwater
# 59396                 river            river/lake      surface
# 59397           machine dbh              borehole  groundwater
# 59398          shallow well          shallow well  groundwater
# 59399          shallow well          shallow well  groundwater
#
#                    waterpoint_type  waterpoint_type_group installer_new  \
# 0               communal standpipe     communal standpipe         other
# 1               communal standpipe     communal standpipe         other
# 2      communal standpipe multiple     communal standpipe  world vision
# 3      communal standpipe multiple     communal standpipe         other
# 4               communal standpipe     communal standpipe         other
# ...                            ...                    ...           ...
# 59395           communal standpipe     communal standpipe           ces
# 59396           communal standpipe     communal standpipe         other
# 59397                    hand pump              hand pump         other
# 59398                    hand pump              hand pump         other
# 59399                    hand pump              hand pump         other
#
#             funder_old    funder_new
# 0                  NaN         roman
# 1                  NaN       grumeti
# 2                  NaN  lottery club
# 3                  NaN        unicef
# 4                  NaN   action in a
# ...                ...           ...
# 59395  germany republi  german group
# 59396              NaN   cefa-njombe
# 59397              NaN         other
# 59398              NaN         malec
# 59399              NaN    world bank
#
# [59400 rows x 42 columns]

# %%
df_train_set['funder_new'].isna().sum()
# Out:
# 0

# %%
df_train_set['funder_new'].value_counts(normalize=True)
# Out:
# government        0.156869
# other             0.074276
# danida            0.052559
# hesawa            0.037323
# kkkt              0.026027
#                     ...
# alia              0.000017
# getekwe           0.000017
# charlotte well    0.000017
# jeshi lawokovu    0.000017
# m                 0.000017
# Name: funder_new, Length: 1683, dtype: float64

# %%
del df_train_set['funder']
del df_train_set['funder_old']

# %%
df_installer_cnt_funder = df_train_set['funder_new'].value_counts(normalize=True)
df_installer_cnt_funder
# Out:
# government        0.156869
# other             0.074276
# danida            0.052559
# hesawa            0.037323
# kkkt              0.026027
#                     ...
# alia              0.000017
# getekwe           0.000017
# charlotte well    0.000017
# jeshi lawokovu    0.000017
# m                 0.000017
# Name: funder_new, Length: 1683, dtype: float64

# %%
df_installer_cnt_funder.head(20)
# Out:
# government            0.156869
# other                 0.074276
# danida                0.052559
# hesawa                0.037323
# kkkt                  0.026027
# district council      0.025051
# church                0.024529
# rwssp                 0.023131
# world bank            0.022710
# world vision          0.021498
# unicef                0.019798
# tasaf                 0.014764
# dhv                   0.013956
# private individual    0.013906
# dwsp                  0.013653
# norad                 0.012879
# finw                  0.012559
# german group          0.012492
# tcrs                  0.010455
# ministry of water     0.009933
# Name: funder_new, dtype: float64

# %%
other_list_funder = df_installer_cnt_funder[df_installer_cnt_funder<.01].index.tolist()
other_list_funder
# Out:
# ['ministry of water',
#  'water',
#  'dwe',
#  'netherlands',
#  'hifab',
#  'adb',
#  'lga',
#  'amref',
#  'oxfam',
#  'wateraid',
#  'isf',
#  'rudep',
#  'private',
#  'jaica',
#  'roman',
#  'rural water supply and sanitat',
#  'community',
#  'adra',
#  'ces(gmbh)',
#  'jica',
#  'shipo',
#  'wsdp',
#  'dh',
#  'ded',
#  'plan int',
#  'kiliwater',
#  'dmdd',
#  'go',
#  'lawatefuka water supply',
#  'oxfarm',
#  'magadini-makiwaru water',
#  'fw',
#  'w.b',
#  'ces (gmbh)',
#  'wvt',
#  'oikos e.afrika',
#  'nethalan',
#  'lvia',
#  'concern world wide',
#  'unhcr',
#  'no',
#  'swedish',
#  'african',
#  'he',
#  'is',
#  'ki',
#  'tardo',
#  'ir',
#  'wananchi',
#  'snv',
#  'wua',
#  'roman catholic',
#  'bsf',
#  'tassaf',
#  'islamic group',
#  'co',
#  'dfid',
#  'lamp',
#  'concern',
#  'muwsa',
#  'villagers',
#  'ru',
#  'halmashauri ya wilaya sikonge',
#  'hsw',
#  'twe',
#  'idc',
#  'tanza',
#  'h',
#  'undp',
#  'mdrdp',
#  'aict',
#  'gtz',
#  'japan',
#  'cmsr',
#  'vwc',
#  'ndrdp',
#  'lwi',
#  'kuwait',
#  'cdtf',
#  'caritas',
#  'padep',
#  'kaemp',
#  'conce',
#  'water aid /sema',
#  'marafip',
#  'cefa',
#  'ncaa',
#  'national rural',
#  'losaa-kia water supply',
#  'md',
#  'irish ai',
#  'sabemo',
#  'plan international',
#  'twesa',
#  'idara ya maji',
#  'tlc',
#  'kirde',
#  'gen',
#  'st',
#  'grumeti',
#  'solidarm',
#  'cocen',
#  'wfp',
#  'tanapa',
#  'ta',
#  'china government',
#  'dwe/norad',
#  'sema',
#  'european union',
#  'solidame',
#  'dwssp',
#  'ridep',
#  'acra',
#  'miziriol',
#  'devon aid korogwe',
#  'dads',
#  'shawasa',
#  'red cross',
#  'redep',
#  'abasia',
#  'tz japan',
#  'giz',
#  'ms',
#  'serikali',
#  'tdft',
#  'donor',
#  'cafod',
#  'soda',
#  'un',
#  'tredep',
#  'ka',
#  'kuwasa',
#  'jbg',
#  'dasip',
#  'fathe',
#  'w',
#  'kidp',
#  'urt',
#  'watu wa ujerumani',
#  'mbiuwasa',
#  'african development bank',
#  'water user as',
#  'si',
#  'aar',
#  'holland',
#  'ilo',
#  'oikos e.africa/european union',
#  'ics',
#  'dhv\\norp',
#  'kiuma',
#  'peters',
#  'tuwasa',
#  'the desk and chair foundat',
#  'biore',
#  'kanisa katoliki lolovoni',
#  'po',
#  'cg',
#  'cspd',
#  'kalta',
#  'peter tesha',
#  'happy watoto foundation',
#  'ga',
#  'swiss if',
#  'jika',
#  'cocern',
#  'il',
#  'kidep',
#  'save the rain usa',
#  'ereto',
#  'water aid/sema',
#  'sida',
#  'undp/ilo',
#  'ifad',
#  'songas',
#  'halmashauri',
#  'partage',
#  'kanisa la menonite',
#  'dw',
#  'lips',
#  'not known',
#  'i wash',
#  'cdcg',
#  'mileniam project',
#  'nethe',
#  'wwf',
#  'quwkwin',
#  'plan internatio',
#  'total land care',
#  'hans',
#  'hewasa',
#  'kilwater',
#  'tacare',
#  'village',
#  'adp',
#  'care international',
#  'kalitasi',
#  'bgm',
#  'tanzakesho',
#  'roman cathoric-same',
#  'rished',
#  'cefa-njombe',
#  'ilct',
#  'wd and id',
#  'sabodo',
#  'cmcr',
#  'bank',
#  'mwaya mn',
#  'vifafi',
#  'singida yetu',
#  'killflora',
#  'swisland/ mount meru flowers',
#  'msf',
#  'norad/ kidep',
#  'sowasa',
#  'kuamu',
#  'magoma adp',
#  'dhv moro',
#  'dct',
#  'efg',
#  'rotary club',
#  'water board',
#  'maji mugumu',
#  'p',
#  'kadp',
#  'makonde water population',
#  'peace cope',
#  'one un',
#  'ubalozi wa marekani',
#  'eu/acra',
#  'gain',
#  'asb',
#  'the people of japan',
#  'tanzania',
#  'ham',
#  'dasp',
#  'cct',
#  'pidp',
#  'mbunge',
#  'drdp ngo',
#  'tasaf/dmdd',
#  'msabi',
#  'mdc',
#  'idydc',
#  'mkuyu',
#  'bahewasa',
#  'sumbawanga munici',
#  'sdg',
#  'bened',
#  'father bonifasi',
#  'ukiligu',
#  'sda',
#  'quick wings',
#  'rdc',
#  'pmo',
#  'tado',
#  'finland government',
#  'mi',
#  'ruthe',
#  'tahea',
#  'lwiji italy',
#  'livin',
#  'bruder',
#  'msikiti',
#  'rwsp',
#  'us embassy',
#  'dar al ber',
#  'resolute mining',
#  'roman cathoric same',
#  'shule',
#  'finland',
#  'elct',
#  'quick wins',
#  'fpct',
#  'african relie',
#  'mamad',
#  'adp mombo',
#  'isf/tacare',
#  'dassip',
#  'living water international',
#  'wfp/tnt/usaid',
#  'private owned',
#  'roman catholic rulenge diocese',
#  'imf',
#  'isingiro ho',
#  'sao h',
#  'franc',
#  'msf/tacare',
#  'ba as',
#  'rural water supply and sanita',
#  'maxavella',
#  'tassaf i',
#  'lgcdg',
#  'undp/aict',
#  'halmashauri ya manispa tabora',
#  'jeica',
#  'benguka',
#  'mosque',
#  'aic',
#  'qwiqwi',
#  'water project mbawala chini',
#  'rada',
#  'bulyahunlu gold mine',
#  'institution',
#  'mh an',
#  'ai',
#  'tridep',
#  'qwickwin',
#  'national rural and hfa',
#  'secondary',
#  'kinapa',
#  'oxfam gb',
#  'kwikwiz',
#  'af',
#  'lifetime',
#  'prf',
#  'canada',
#  'lowasa',
#  'rips',
#  'idea',
#  'germany misionary',
#  'dak',
#  'unicef/central',
#  'wfp/tnt',
#  'snv ltd',
#  'millenium',
#  'kmcl',
#  'auwasa',
#  'belgian government',
#  'tasafu',
#  'chamavita',
#  'tag',
#  'de',
#  'sijm',
#  'nado',
#  'suwasa',
#  'kadres ngo',
#  'holla',
#  'bffs',
#  'kingupira s',
#  'aimgold',
#  'serikali ya kijiji',
#  'mzinga a',
#  'regional water engineer arusha',
#  'pci',
#  'ikela wa',
#  'w.d & i.',
#  'water user group',
#  'kanisa',
#  'action contre la faim',
#  'hortanzia',
#  'desk and chair foundation',
#  'tassaf ii',
#  'people of japan',
#  'koica',
#  'healt',
#  'women for partnership',
#  'williamson diamond ltd',
#  'mem',
#  'cobashec',
#  'camavita',
#  'angrikana',
#  'british colonial government',
#  'action aid',
#  'i.e.c',
#  'duwas',
#  'tltc',
#  'halmashaur',
#  'rundu man',
#  'roman cathoric -kilomeni',
#  'moroil',
#  'member of parliament',
#  'd',
#  'br',
#  'mamlaka ya maji ngara',
#  'france',
#  'olumuro',
#  'do',
#  'professor ben ohio university',
#  'mtuwasa',
#  'nk',
#  'lottery club',
#  'ebaha',
#  'milenia',
#  'kilomber',
#  'baric',
#  'mws',
#  'bs',
#  'hapa',
#  'el',
#  'abd',
#  'lawate fuka water suppl',
#  'unicef/ csp',
#  'sauwasa',
#  'kanisa katoliki',
#  'school',
#  'summit for water',
#  'menon',
#  'local',
#  'parastatal',
#  'rwsssp',
#  'africare',
#  'villa',
#  'u.s.a',
#  'filo',
#  'adf',
#  'moslem foundation',
#  'gaica',
#  'gt',
#  'total landcare',
#  'rwssp/wsdp',
#  'ministry of education',
#  'vttp',
#  'caltus',
#  'mboma',
#  'makonde',
#  'clause',
#  'ngos',
#  'dawasco',
#  'in',
#  'w.d &',
#  'wfp/usaid/tnt',
#  'robert loyal',
#  'obc',
#  'kimkuma',
#  'pataji',
#  're',
#  'mac',
#  'quick',
#  'secondary schoo',
#  'mzungu paul',
#  'wate aid/sema',
#  'semaki k',
#  'jeshi la wokovu',
#  'african development foundation',
#  'sanje wa',
#  'jimbo fund',
#  'tulawaka gold mine',
#  'kigoma municipal',
#  'cbhi',
#  'wanan',
#  'tabraki',
#  'cpro',
#  'bilila',
#  'wrssp',
#  'jgb',
#  'mdgwc',
#  'usaid/wfp',
#  'dbspe',
#  'walokole',
#  'nsc',
#  'kirdep',
#  'regwa company of egypt',
#  'krp',
#  'hospital',
#  'runduman',
#  'caltas',
#  'greec',
#  'lions club',
#  'japan food',
#  'ea',
#  'domestic rural development pro',
#  'st ph',
#  'ilkeri village',
#  'trachoma',
#  'priva',
#  'balo',
#  'brdp',
#  'safari roya',
#  'dmk',
#  'w.c.s',
#  'uhai wa mama na mtoto',
#  'handeni trunk main(',
#  'tumaini fund',
#  'ola',
#  'tanap',
#  'ddp',
#  'asdp',
#  'losakia water supply',
#  'mgm',
#  'mp mzeru',
#  'christian outrich',
#  't',
#  'hiap',
#  'diocese of geita',
#  'institutional',
#  'tanesco',
#  'oldonyolengai',
#  'mavuno ngo',
#  'farm africa',
#  'minis',
#  'cast',
#  'cpps',
#  'longido sec school',
#  'cartas tanzania',
#  'kashwas',
#  'sweden',
#  'concen',
#  'netherland',
#  'cdg',
#  'kijiji',
#  'loliondo parish',
#  'roman ca',
#  'loliondo secondary',
#  'mwanga town water authority',
#  'tgts',
#  'oikos e .africa/european union',
#  'totoland care',
#  'moravian',
#  'lench',
#  'konoike',
#  'lions',
#  'saleh zaharani',
#  'pad',
#  'quickwi',
#  'simmors',
#  'geochaina',
#  'rural drinking water supply',
#  'adap',
#  'wvc',
#  'lcgd',
#  'nyamongo gold mining',
#  'bridge north',
#  'nrwssp',
#  'wizara',
#  'musilim agency',
#  'unknown',
#  'magadini makiwaru water',
#  'udc/sema',
#  'patuu',
#  'diwani',
#  'doddea',
#  'halmashauri ya wilaya',
#  'liuwassa',
#  'enyueti',
#  'nduku village',
#  'kmt',
#  'uyoge',
#  'mmem',
#  'eu',
#  'ggm',
#  'rotary i',
#  'ukida',
#  'presadom',
#  'engin',
#  'tanroad',
#  'mianz',
#  'gachuma ginery',
#  'wfp/usaid',
#  'lidep',
#  'acord',
#  'ifakara',
#  'miomb',
#  'tirdo',
#  'awf',
#  'rvemp',
#  'lgcbg',
#  'rssp',
#  'wama',
#  'cipro/care',
#  'pr',
#  'belgij',
#  'rotte',
#  'usaid',
#  'wssp',
#  'serena',
#  'kiwanda cha tangawizi',
#  'dhinu',
#  'irevea sister',
#  'dadp',
#  'hindu',
#  'oikos',
#  'floresta',
#  'mtibwa s',
#  'vi',
#  'geita goldmain',
#  'simavi',
#  'zao water spring',
#  'quik',
#  'italy government',
#  'bingo foundation',
#  'vodacom',
#  'minjingu',
#  'bobby',
#  'stantons',
#  'ro',
#  'quick win project',
#  'mwelia estate',
#  'japan embassy',
#  'sswp',
#  'korea',
#  'ustawi',
#  'anjuman e seifee',
#  'lake tanganyika',
#  'mh kapuya',
#  'lcdg',
#  'japan aid',
#  'water sector development',
#  'unesco',
#  'usa embassy',
#  'sw',
#  'f',
#  'selous g',
#  'schoo',
#  'makonde water supply',
#  'shanta',
#  'tanz egypt technical cooper',
#  'w.d.&.i.',
#  'soliderm',
#  'l',
#  'nassor fehed',
#  'uhoranzi',
#  'serikari',
#  'dwt',
#  'mzee don',
#  'mchukwi hos',
#  'vickfis',
#  'greinaker',
#  'rural water supply',
#  'lgdcg',
#  'tpp',
#  'cheni',
#  'lvemp',
#  'malec',
#  'h/w',
#  'morovian',
#  'dbfpe',
#  'iran gover',
#  'kerebuka',
#  'regwa company of egpty',
#  'holand',
#  'ikeuchi towels japan',
#  'insututional',
#  'nddp',
#  'friends of kibara foundation',
#  'villaers',
#  'tadepa',
#  'eno',
#  'domestic water supply project',
#  'tom',
#  'foreigne',
#  'nirad',
#  'italy',
#  'gwitembe',
#  'lga and adb',
#  'lotary club',
#  'solar villa',
#  'nchagwa',
#  'svn',
#  'mwita muremi',
#  'company',
#  'redap',
#  'moradi',
#  'cipro',
#  'redeso',
#  'g.d&i.d',
#  'rwssp shinyanga',
#  'tempo',
#  'totoland',
#  'oda',
#  'judge mchome',
#  'wspd',
#  'kibaha independent school',
#  'village fund',
#  'bokera w',
#  'nwssp',
#  'chacha',
#  'none',
#  'makuru',
#  'redcross',
#  'kdrdp ngo',
#  'ruped',
#  'rocci ross',
#  'dioce',
#  'wua and ded',
#  'ten degree hotel',
#  'ardhi instute',
#  'kambi migoko',
#  'sawaka',
#  'british tanza',
#  'cgi',
#  'dsp',
#  'halmashauri wil',
#  'c',
#  'father w',
#  'denish',
#  'uvimaki',
#  'dmo',
#  'irish government',
#  'mama mery nagu',
#  'k',
#  'egypt',
#  'q-sem ltd',
#  'lwf',
#  'kombe foundation',
#  'maro',
#  'vififi',
#  'omary issa',
#  'unicef/cspd',
#  'africa 2000 network/undp',
#  'ministry of healthy',
#  'wsdp & sdg',
#  's',
#  'mashaka',
#  'chani',
#  'african realief committe of ku',
#  'sister francis',
#  "tag patmo's",
#  'kibo brewaries',
#  'tasaf and lga',
#  'compa',
#  'juhibu',
#  'kiwanda cha samaki',
#  'cip',
#  'snv-swash',
#  'senapa',
#  'denat',
#  'swash',
#  'acord ngo',
#  'global fund',
#  'norad/ tassaf',
#  'cope',
#  'un/wfp',
#  'halmashauli',
#  'scott',
#  'investor',
#  'mzung',
#  'mtc',
#  'dawasa',
#  'zaben',
#  'jimmy',
#  'care/cipro',
#  'roman cathoric',
#  'lench taramai',
#  'greineker',
#  'mwl. nyerere sec. school',
#  'socie',
#  'adp/w',
#  'mataro',
#  'mp',
#  'sua',
#  'magereza',
#  'laramatak',
#  'people from japan',
#  'makoye masanzu',
#  'game fronti',
#  'hpa',
#  'niger',
#  'kwik',
#  'vicfish',
#  'fptc - pent',
#  'railway',
#  'norad/ tassaf ii',
#  'egypt government',
#  'africa',
#  'ox',
#  'bread for the wor',
#  'adp bungu',
#  'htm',
#  'kata',
#  'peter',
#  'vifaf',
#  'swisland/mount meru flowers',
#  'tlc/john majala',
#  'kyariga',
#  'rafik',
#  'mmg gold mine',
#  'resolute',
#  'kibo',
#  'wajerumani',
#  'tasef',
#  'muhameid na',
#  'bio fuel company',
#  'mwigicho',
#  'others',
#  'abood',
#  'mzee omari',
#  'lisa',
#  'african 2000 network',
#  'village office',
#  'dmmd',
#  'rombo dalta',
#  'kfw',
#  'singasinga',
#  'fao',
#  'vicfish ltd',
#  'rural water department',
#  'africa amini alama',
#  'school adm9nstrarion',
#  'calvary connect',
#  'african barrick gold',
#  'gesawa',
#  'jumanne siabo',
#  'vwt',
#  'lusajo',
#  'timothy shindika',
#  'seronera',
#  'yasi naini',
#  'taasaf',
#  'ester ndege',
#  'msigwa',
#  'mwalimu muhenza',
#  'swifti',
#  'engineers without border',
#  'gg',
#  'japan government',
#  'gra na halmashauri',
#  'chmavita',
#  'tbl',
#  'ahmadia',
#  'mwita lucas',
#  'quicklw',
#  'padi',
#  'tlc/jenus malecha',
#  'mamaz',
#  'stephano paulo',
#  'aqua blues angels',
#  'friends of ulambo and mwanhala',
#  'tlc/nyengesa masanja',
#  'jacobin',
#  'quick wins scheme',
#  'chama cha ushirika',
#  'taees',
#  'comunedi roma',
#  'water aid/dwe',
#  'fida',
#  'lake tanganyika basin',
#  'shinyanga shallow wells',
#  'esawa',
#  'ruvu darajani',
#  'totaland care',
#  'dmk anglican',
#  'st gasper',
#  'dasiip',
#  'insititutiona',
#  'sweeden',
#  'water department',
#  'lion clu',
#  's.s mohamed',
#  'mungaya',
#  'babtest',
#  'college',
#  'zao water spring x',
#  'semaki',
#  'dmd',
#  'lions c',
#  'kolopin',
#  'samlo',
#  'abas ka',
#  'eco lodge',
#  'jafary mbaga',
#  'gdp',
#  'drdp',
#  'wame mbiki',
#  'water authority',
#  'hasnein murij',
#  'wamarekani',
#  'vw',
#  'petro patrice',
#  'tanzaling',
#  'mhoranzi',
#  'rarymond ekura',
#  'muivaru',
#  'subvillage',
#  'romam catholic',
#  'ndorobo tours',
#  'sent tho',
#  'wcst',
#  'sunamco',
#  'friend from un',
#  'mow',
#  'luke samaras ltd',
#  'hapa singida',
#  'africaone ltd',
#  'koico',
#  'mamvua kakungu',
#  'mwita kichere',
#  'jipa',
#  'sadaqatun jar',
#  'bgssws',
#  'makli',
#  'masista',
#  'taipo',
#  'pius msekwa',
#  'fiwater',
#  'robert mosi',
#  'piscope',
#  'fresh water plc england',
#  'fosecu',
#  'kahema',
#  "rashid seng'ombe",
#  'rwi',
#  'caltaz kahama',
#  'hashi',
#  'pentecost',
#  'nazaleti',
#  'mhina',
#  'justine marwa',
#  'sagaswe',
#  'kayempu ltd',
#  'lizad',
#  'simba lodge',
#  'noshad',
#  'nyitamboka',
#  'waheke',
#  'shule ya msingi',
#  'mnyama',
#  'aixos',
#  'theonas mnyama',
#  'magige',
#  'wamisionari wa kikatoriki',
#  'village contributio',
#  'john skwese',
#  'japan food aid',
#  'bukumbi',
#  'rotary',
#  'sido',
#  'simone',
#  'gurdians',
#  'mwingereza',
#  'village res',
#  'samweli',
#  'paulo sange',
#  'ldcgd',
#  'songa hospi',
#  'morrovian',
#  'mbwana omari',
#  'people of sweden',
#  'makona',
#  'arabi',
#  'moses',
#  'meru concrete',
#  'twende pamoja',
#  'netherla',
#  'mrtc',
#  'zinduka',
#  'mnyambe',
#  'umoja',
#  'raramataki',
#  'nssf',
#  'matogoro',
#  'meko balo',
#  'meco',
#  'hez',
#  'magani',
#  'matyenye',
#  'erre kappa',
#  'rumaki',
#  'kalitesi',
#  'mgaya',
#  'mwalimu  maneromango muhenzi',
#  'embasy of japan in tanzania',
#  'mbozi hospital',
#  'bonite bottles ltd',
#  'said salum ally',
#  'singsinga',
#  'kapelo',
#  'shabani dunia',
#  'dmdd/solider',
#  'wbk',
#  'maswi drilling co. ltd',
#  'sipdo',
#  'jwtz',
#  'lungwe',
#  'gerald tuseko gro',
#  'serikaru',
#  'siza mayengo',
#  'tingatinga sec school',
#  'opec',
#  'godii',
#  'matimbwa sec',
#  'loocip',
#  'lake tanganyika prodap',
#  'folac',
#  'maliasili',
#  'masai land',
#  'masese',
#  'amrefe',
#  'nyamasagi',
#  'hilfe fur brunder',
#  'handeni trunk maini',
#  'prof. saluati',
#  'dhv\\swis',
#  'ded/rwssp',
#  'maju mugumu',
#  'teresa munyama',
#  'enyuati',
#  'dacp',
#  'mstiiti',
#  'rafael michael',
#  'msikiti masji',
#  'tanzania egypt technical co op',
#  'rudep/norad',
#  'namungo miners',
#  'machibya guma',
#  'pentecostal hagana sweeden',
#  'soko la magomeni',
#  'boazi /o',
#  'dwarf',
#  'rotary club australia',
#  'apm',
#  ...]

# %%
df_train_set['funder_new'].replace(to_replace=other_list_funder, value='other', inplace=True)
df_train_set['funder_new'].value_counts(normalize=True)
# Out:
# other                 0.485842
# government            0.156869
# danida                0.052559
# hesawa                0.037323
# kkkt                  0.026027
# district council      0.025051
# church                0.024529
# rwssp                 0.023131
# world bank            0.022710
# world vision          0.021498
# unicef                0.019798
# tasaf                 0.014764
# dhv                   0.013956
# private individual    0.013906
# dwsp                  0.013653
# norad                 0.012879
# finw                  0.012559
# german group          0.012492
# tcrs                  0.010455
# Name: funder_new, dtype: float64

# %% [markdown]
# ### Group Other Remaining Columns

# %%
def group_other(col,perc):
    df_train_set[col] = df_train_set[col].astype(str).str.lower()
    df_cnt = df_train_set[col].value_counts(normalize=True)
    other_list = df_cnt[df_cnt<perc].index.tolist()
    

    return df_train_set[col].replace(to_replace=other_list, value='other', inplace=True)
    print(df_train_set[col].value_counts(normalize=True,dropna=False))

# %% [markdown]
# #### lga

# %%
df_train_set['lga'].value_counts(normalize=True,dropna=False)
# Out:
# Njombe          0.042138
# Arusha Rural    0.021077
# Moshi Rural     0.021061
# Bariadi         0.019815
# Rungwe          0.018620
#                   ...
# Moshi Urban     0.001330
# Kigoma Urban    0.001195
# Arusha Urban    0.001061
# Lindi Urban     0.000354
# Nyamagana       0.000017
# Name: lga, Length: 125, dtype: float64

# %%
group_other('lga',.01)

# %%
df_train_set['lga'].value_counts(normalize=True,dropna=False)
# Out:
# other            0.475438
# njombe           0.042138
# arusha rural     0.021077
# moshi rural      0.021061
# bariadi          0.019815
# rungwe           0.018620
# kilosa           0.018418
# kasulu           0.017626
# mbozi            0.017407
# meru             0.016987
# bagamoyo         0.016785
# singida rural    0.016751
# kilombero        0.016145
# same             0.014764
# kibondo          0.014714
# kyela            0.014461
# kahama           0.014074
# kigoma rural     0.013872
# magu             0.013872
# maswa            0.013620
# karagwe          0.012980
# mbinga           0.012626
# iringa rural     0.012256
# serengeti        0.012054
# namtumbo         0.011684
# lushoto          0.011684
# songea rural     0.011667
# mpanda           0.011431
# mvomero          0.011296
# ngara            0.011263
# ulanga           0.011195
# makete           0.010606
# kwimba           0.010556
# mbarali          0.010539
# hai              0.010522
# rombo            0.010000
# Name: lga, dtype: float64

# %% [markdown]
# ## Columns to drop

# %% [markdown]
# ### Mostly Empty

# %%
df_train_set['num_private'].value_counts(normalize=True,dropna=False)
# Out:
# 0      0.987256
# 6      0.001364
# 1      0.001229
# 5      0.000774
# 8      0.000774
#          ...
# 180    0.000017
# 213    0.000017
# 23     0.000017
# 55     0.000017
# 94     0.000017
# Name: num_private, Length: 65, dtype: float64

# %% [markdown]
# ### Many Individual Values

# %%
df_train_set['wpt_name'].value_counts(normalize=True,dropna=False)
# Out:
# none          0.059983
# Shuleni       0.029428
# Zahanati      0.013973
# Msikitini     0.009007
# Kanisani      0.005438
#                 ...
# Kaselia       0.000017
# Kwamgoloka    0.000017
# Tuokoe 1      0.000017
# Drewa         0.000017
# Mwika         0.000017
# Name: wpt_name, Length: 37400, dtype: float64

# %%
df_train_set['ward'].value_counts(normalize=True,dropna=False)
# Out:
# Igosi              0.005168
# Imalinyi           0.004242
# Siha Kati          0.003906
# Mdandu             0.003889
# Nduruma            0.003653
#                      ...
# Izia               0.000017
# Nyamtinga          0.000017
# Kitete             0.000017
# Uwanja wa Ndege    0.000017
# Thawi              0.000017
# Name: ward, Length: 2092, dtype: float64

# %% [markdown]
# ### Not Significant

# %% [markdown]
# #### The features scheme_management, quantity_group, water_quality, region_code, payment_type, extraction_type, waterpoint_type_group, date_recorded, and recorded_by will be deleted for duplicate information.

# %%
def drop(df):
# Columns to drop
    df.drop([
        'scheme_management', 'quantity_group', 'water_quality', 'region', 'payment_type',
        'extraction_type', 'extraction_type_class','source','waterpoint_type_group', 'date_recorded', 'recorded_by',
        'subvillage', 'public_meeting', 'scheme_name','wpt_name','ward','num_private'],
        axis=1, inplace=True)
    return df

# %% [markdown]
# To do: look at feat importance of different geographic features remaining
#
# - basin — Geographic water basin
# - subvillage — Geographic location
# - region_code — Geographic location (coded)
# - district_code — Geographic location (coded)
# - lga — Geographic location
# - ward — Geographic location

# %% [markdown]
# ## Categorical and Numerical

# %%
categorical = ['basin','region_code', 'district_code', 'lga','permit','construction_year',
               'extraction_type_group','management','management_group', 'payment', 
               'quality_group', 'quantity','source_type','source_class', 'waterpoint_type',
               'installer_new', 'funder_new']
#longitude, lattitude

# %%
for column in categorical:
    plt.hist(df_train_set[column])
    plt.xlabel(column)
    plt.title("{} Distribution".format(column))
    plt.show()

# %% [markdown]
# ### Join Target: df_train_set to df_train

# %%
df_train = df_train_set.join(df_train_labels, on='id', how='left', lsuffix='_left', rsuffix='_right')
df_train = drop(df_train)

df_test = drop(df_test)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59400 entries, 0 to 59399
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_left                59400 non-null  int64
#  1   amount_tsh             59400 non-null  float64
#  2   gps_height             59400 non-null  int64
#  3   longitude              59400 non-null  float64
#  4   latitude               59400 non-null  float64
#  5   basin                  59400 non-null  object
#  6   region_code            59400 non-null  int64
#  7   district_code          59400 non-null  int64
#  8   lga                    59400 non-null  object
#  9   population             59400 non-null  int64
#  10  permit                 59400 non-null  int64
#  11  construction_year      59400 non-null  int64
#  12  extraction_type_group  59400 non-null  object
#  13  management             59400 non-null  object
#  14  management_group       59400 non-null  object
#  15  payment                59400 non-null  object
#  16  quality_group          59400 non-null  object
#  17  quantity               59400 non-null  object
#  18  source_type            59400 non-null  object
#  19  source_class           59400 non-null  object
#  20  waterpoint_type        59400 non-null  object
#  21  installer_new          59400 non-null  object
#  22  funder_new             59400 non-null  object
#  23  id_right               47492 non-null  float64
#  24  status_group           47492 non-null  object
# dtypes: float64(4), int64(7), object(14)
# memory usage: 11.8+ MB

# %%
df_train.columns
# Out:
# Index(['id_left', 'amount_tsh', 'gps_height', 'longitude', 'latitude', 'basin',
#        'region_code', 'district_code', 'lga', 'population', 'permit',
#        'construction_year', 'extraction_type_group', 'management',
#        'management_group', 'payment', 'quality_group', 'quantity',
#        'source_type', 'source_class', 'waterpoint_type', 'installer_new',
#        'funder_new', 'id_right', 'status_group'],
#       dtype='object')

# %%
df_train['status_group'].value_counts(normalize=True,dropna=False)
# Out:
# functional                 0.436229
# non functional             0.305522
# NaN                        0.200471
# functional needs repair    0.057778
# Name: status_group, dtype: float64

# %%
df_train.loc[df_train['amount_tsh'] == 0]
# Out:
#        id_left  amount_tsh  gps_height  longitude   latitude  \
# 1         8776         0.0        1399  34.698766  -2.147466
# 3        67743         0.0         263  38.486161 -11.155298
# 4        19728         0.0           0  31.130847  -1.825359
# 6        19816         0.0           0  33.362410  -3.766365
# 7        54551         0.0           0  32.620617  -4.226198
# ...        ...         ...         ...        ...        ...
# 59392    40607         0.0           0  33.009440  -8.520888
# 59393    48348         0.0           0  33.866852  -4.287410
# 59397    37057         0.0           0  34.017087  -8.750434
# 59398    31282         0.0           0  35.861315  -6.378573
# 59399    26348         0.0         191  38.104048  -6.747464
#
#                          basin  region_code  district_code        lga  \
# 1                Lake Victoria           20              2  serengeti
# 3      Ruvuma / Southern Coast           90             63      other
# 4                Lake Victoria           18              1    karagwe
# 6                     Internal           17              3      other
# 7              Lake Tanganyika           17              3     kahama
# ...                        ...          ...            ...        ...
# 59392               Lake Rukwa           12              1      other
# 59393                 Internal           14              2      other
# 59397                   Rufiji           12              7    mbarali
# 59398                   Rufiji            1              4      other
# 59399              Wami / Ruvu            5              2      other
#
#        population  ...                payment  quality_group      quantity  \
# 1             280  ...              never pay           good  insufficient
# 3              58  ...              never pay           good           dry
# 4               0  ...              never pay           good      seasonal
# 6               0  ...              never pay           good        enough
# 7               0  ...                unknown          milky        enough
# ...           ...  ...                    ...            ...           ...
# 59392           0  ...              never pay           good        enough
# 59393           0  ...         pay per bucket           good  insufficient
# 59397           0  ...            pay monthly       fluoride        enough
# 59398           0  ...              never pay           good  insufficient
# 59399         150  ...  pay when scheme fails          salty        enough
#
#                 source_type source_class              waterpoint_type  \
# 1      rainwater harvesting      surface           communal standpipe
# 3                  borehole  groundwater  communal standpipe multiple
# 4      rainwater harvesting      surface           communal standpipe
# 6                  borehole  groundwater                    hand pump
# 7              shallow well  groundwater                    hand pump
# ...                     ...          ...                          ...
# 59392                spring  groundwater           communal standpipe
# 59393                   dam      surface                        other
# 59397              borehole  groundwater                    hand pump
# 59398          shallow well  groundwater                    hand pump
# 59399          shallow well  groundwater                    hand pump
#
#               installer_new  funder_new id_right    status_group
# 1                     other       other  13732.0  non functional
# 3                     other      unicef      NaN             NaN
# 4                     other       other  45242.0      functional
# 6                       dwe        dwsp   3055.0  non functional
# 7                       dwe       rwssp  59779.0      functional
# ...                     ...         ...      ...             ...
# 59392  tanzanian government  government   9606.0  non functional
# 59393                 other       other  33124.0      functional
# 59397                 other       other  57735.0      functional
# 59398                 other       other   9495.0      functional
# 59399                 other  world bank  39933.0      functional
#
# [41639 rows x 25 columns]

# %%
numerical = ['amount_tsh','gps_height','population']

# %%
numerical_large = ['gps_height','population']

# %%
numerical_small = ['amount_tsh']

# %%
# for column in categorical:
#     sns.countplot(x=df_train[column], hue=df_train['status_group'], data=df_train, palette="Greens_d")
# #     df_house.plot.scatter(x=column, y='price')
# #     plt.title("{} vs. Sales Price".format(column))
# #     plt.show()

# %%
for variable in numerical_large:
    ax, figure = plt.subplots(1,1,figsize=(12,12))
    plt.ylim(-100,2500)
    sns.boxplot(x='status_group', y=variable, data=df_train)
    plt.title("{} vs. Well Condition".format(variable))

# %%
del df_train['gps_height']
del df_train['population']

# %%
for variable in numerical_small:
    ax, figure = plt.subplots(1,1,figsize=(12,12))
    plt.ylim(-1,200)
    sns.boxplot(x='status_group', y=variable, data=df_train)
    plt.title("{} vs. Well Condition".format(variable))

# %%
# for column in numerical_small:
#     plt.hist(df_train_set[column])
#     plt.xlabel(column)
#     plt.title("{} Distribution".format(column))
#     plt.show()

# %% [markdown]
# ### Column Binning

# %%
year_plot = ['construction_year']

# %%
for column in year_plot:
    plt.hist(df_train[column])
    plt.xlabel(column)
    plt.title("{} Distribution".format(column))
    plt.show()

# %%
bin_features = ['amount_tsh','construction_year']

# %%
df_train['construction_year'].value_counts(normalize=True,dropna=False)
# Out:
# 0       0.348636
# 2010    0.044529
# 2008    0.043990
# 2009    0.042643
# 2000    0.035202
# 2007    0.026717
# 2006    0.024764
# 2003    0.021650
# 2011    0.021145
# 2004    0.018906
# 2012    0.018249
# 2002    0.018098
# 1978    0.017458
# 1995    0.017071
# 2005    0.017020
# 1999    0.016481
# 1998    0.016263
# 1990    0.016061
# 1985    0.015909
# 1980    0.013653
# 1996    0.013653
# 1984    0.013114
# 1982    0.012525
# 1994    0.012424
# 1972    0.011919
# 1974    0.011380
# 1997    0.010842
# 1992    0.010774
# 1993    0.010236
# 2001    0.009091
# 1988    0.008771
# 1983    0.008215
# 1975    0.007357
# 1986    0.007306
# 1976    0.006970
# 1970    0.006919
# 1991    0.005455
# 1989    0.005320
# 1987    0.005084
# 1981    0.004007
# 1977    0.003401
# 1979    0.003232
# 1973    0.003098
# 2013    0.002963
# 1971    0.002441
# 1960    0.001717
# 1967    0.001481
# 1963    0.001431
# 1968    0.001296
# 1969    0.000993
# 1964    0.000673
# 1962    0.000505
# 1961    0.000354
# 1965    0.000320
# 1966    0.000286
# Name: construction_year, dtype: float64

# %%
df_train['amount_tsh'].value_counts(normalize=True,dropna=False)
# Out:
# 0.0         0.700993
# 500.0       0.052222
# 50.0        0.041616
# 1000.0      0.025051
# 20.0        0.024630
#               ...
# 8500.0      0.000017
# 6300.0      0.000017
# 220.0       0.000017
# 138000.0    0.000017
# 12.0        0.000017
# Name: amount_tsh, Length: 98, dtype: float64

# %%
df_train.amount_tsh.fillna(0, inplace=True)

# %%
# and we will also take a look at their summary statistics
for feat in bin_features:
    print(df_train[feat].describe())
# Out:
# count     59400.000000
# mean        317.650385
# std        2997.574558
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          20.000000
# max      350000.000000
# Name: amount_tsh, dtype: float64
# count    59400.000000
# mean      1300.652475
# std        951.620547
# min          0.000000
# 25%          0.000000
# 50%       1986.000000
# 75%       2004.000000
# max       2013.000000
# Name: construction_year, dtype: float64

# %%
# based on some intuition and the quantile distributions, we will define our bin ranges.
tsh_bins = [-1,0,20,350000]
construction_year_bins = [0,1,1985,2005,2015]

# %%
# now lets convert these columns to binned categories
# note that when binning these, the default setting is that the values on the right are included in the bin

df_train['amount_tsh'] = pd.cut(df_train['amount_tsh'], tsh_bins)
df_train['construction_year'] = pd.cut(df_train['construction_year'], construction_year_bins)

# %%
# and we will also take a look at the distribution across bins 
for feat in bin_features:
    print(df_train[feat].value_counts(normalize=True, dropna=False))
# Out:
# (-1, 0]         0.700993
# (20, 350000]    0.249495
# (0, 20]         0.049512
# Name: amount_tsh, dtype: float64
# NaN                 0.348636
# (1985.0, 2005.0]    0.275707
# (2005.0, 2015.0]    0.225000
# (1.0, 1985.0]       0.150657
# (0.0, 1.0]          0.000000
# Name: construction_year, dtype: float64

# %%
# sns.countplot(x=df_train['amount_tsh'], hue=df_train['status_group'], data=df_train, palette="Greens_d")

# %%
df_train['amount_tsh'].value_counts(normalize=True, dropna=False)
# Out:
# (-1, 0]         0.700993
# (20, 350000]    0.249495
# (0, 20]         0.049512
# Name: amount_tsh, dtype: float64

# %%
df_train['amount_tsh']
# Out:
# 0        (20, 350000]
# 1             (-1, 0]
# 2        (20, 350000]
# 3             (-1, 0]
# 4             (-1, 0]
#              ...
# 59395         (0, 20]
# 59396    (20, 350000]
# 59397         (-1, 0]
# 59398         (-1, 0]
# 59399         (-1, 0]
# Name: amount_tsh, Length: 59400, dtype: category
# Categories (3, interval[int64]): [(-1, 0] < (0, 20] < (20, 350000]]

# %%
df_train['amount_tsh'].value_counts(normalize=True, dropna=False)
# Out:
# (-1, 0]         0.700993
# (20, 350000]    0.249495
# (0, 20]         0.049512
# Name: amount_tsh, dtype: float64

# %%
df_train.columns
# Out:
# Index(['id_left', 'amount_tsh', 'longitude', 'latitude', 'basin',
#        'region_code', 'district_code', 'lga', 'permit', 'construction_year',
#        'extraction_type_group', 'management', 'management_group', 'payment',
#        'quality_group', 'quantity', 'source_type', 'source_class',
#        'waterpoint_type', 'installer_new', 'funder_new', 'id_right',
#        'status_group'],
#       dtype='object')

# %% [markdown]
# ### Encode Features

# %%
df_train['status_group'].value_counts(normalize=True, dropna=False)
# Out:
# functional                 0.436229
# non functional             0.305522
# NaN                        0.200471
# functional needs repair    0.057778
# Name: status_group, dtype: float64

# %%
df_train.status_group.fillna(0, inplace=True)

# %%
df_train['status_group'].value_counts(normalize=True, dropna=False)
# Out:
# functional                 0.436229
# non functional             0.305522
# 0                          0.200471
# functional needs repair    0.057778
# Name: status_group, dtype: float64

# %%
df_train.columns
# Out:
# Index(['id_left', 'amount_tsh', 'longitude', 'latitude', 'basin',
#        'region_code', 'district_code', 'lga', 'permit', 'construction_year',
#        'extraction_type_group', 'management', 'management_group', 'payment',
#        'quality_group', 'quantity', 'source_type', 'source_class',
#        'waterpoint_type', 'installer_new', 'funder_new', 'id_right',
#        'status_group'],
#       dtype='object')

# %%
col_names = list(df_train.columns)
# col_names = col_names.remove('permit','id_left','id_right','status_group')

# %%
# col_names.remove('longitude')
# col_names.remove('latitude')
col_names.remove('id_left')
col_names.remove('id_right')

# %%
remove_ohe = ['permit','status_group','longitude','latitude']

# %%
col_names_ohe = col_names

# %%
for ele in remove_ohe:
    if ele in col_names_ohe:
        col_names_ohe.remove(ele)
col_names_ohe
# Out:
# ['amount_tsh',
#  'basin',
#  'region_code',
#  'district_code',
#  'lga',
#  'construction_year',
#  'extraction_type_group',
#  'management',
#  'management_group',
#  'payment',
#  'quality_group',
#  'quantity',
#  'source_type',
#  'source_class',
#  'waterpoint_type',
#  'installer_new',
#  'funder_new']

# %%
#for ele in col_names_ohe:
#    if ele in remove_ohe:
#        col_names_ohe.remove(ele)
#col_names_ohe

# %% [markdown]
# # Train Test Split

# %%
df_train['status_group'].value_counts(normalize=True,dropna=False)
# Out:
# functional                 0.436229
# non functional             0.305522
# 0                          0.200471
# functional needs repair    0.057778
# Name: status_group, dtype: float64

# %%
# delte rows where prediction values did not join
df_train = df_train[df_train.status_group != 0]

# %%
X=df_train.drop(columns = ['id_right','id_left', 'status_group']) # Features
y=df_train['status_group']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

# %%
X_train[col_names] = X_train[col_names_ohe].astype('category')
X_test[col_names] = X_test[col_names_ohe].astype('category')

# %%
X_train
# Out:
#          amount_tsh  longitude   latitude                    basin  \
# 49542  (20, 350000]  37.775982  -7.097974              Wami / Ruvu
# 34069       (0, 20]  38.660796  -5.805560                  Pangani
# 50671  (20, 350000]  35.931710  -8.269781                   Rufiji
# 47695  (20, 350000]  33.963904  -9.244679               Lake Nyasa
# 22975       (-1, 0]  34.048313  -3.514827                 Internal
# ...             ...        ...        ...                      ...
# 9376        (-1, 0]  35.973434  -5.000566                 Internal
# 20299       (-1, 0]  39.888784 -10.283240  Ruvuma / Southern Coast
# 6503   (20, 350000]  35.101033  -9.881352               Lake Nyasa
# 54761       (-1, 0]  35.054737  -8.376268                   Rufiji
# 1976   (20, 350000]  34.328575  -4.855217                 Internal
#
#       region_code district_code            lga  permit construction_year  \
# 49542           5             2          other       1  (2005.0, 2015.0]
# 34069           4             6          other       0  (2005.0, 2015.0]
# 50671          11             7          other       1  (2005.0, 2015.0]
# 47695          11             3         makete       0  (1985.0, 2005.0]
# 22975          17             2          maswa       0               NaN
# ...           ...           ...            ...     ...               ...
# 9376            1             1          other       0               NaN
# 20299          99             1          other       1     (1.0, 1985.0]
# 6503           11             5          other       0  (1985.0, 2005.0]
# 54761          11             2          other       1               NaN
# 1976           13             2  singida rural       0  (1985.0, 2005.0]
#
#       extraction_type_group management management_group         payment  \
# 49542               gravity        vwc       user-group     pay monthly
# 34069           submersible        vwc       user-group  pay per bucket
# 50671               gravity        vwc       user-group    pay annually
# 47695               gravity        vwc       user-group     pay monthly
# 22975           nira/tanira        wug       user-group           other
# ...                     ...        ...              ...             ...
# 9376        other motorpump        vwc       user-group  pay per bucket
# 20299                 other        vwc       user-group         unknown
# 6503                gravity        vwc       user-group     pay monthly
# 54761                swn 80        vwc       user-group    pay annually
# 1976                afridev        vwc       user-group  pay per bucket
#
#       quality_group      quantity   source_type source_class  \
# 49542          good  insufficient    river/lake      surface
# 34069         salty  insufficient      borehole  groundwater
# 50671          good        enough        spring  groundwater
# 47695          good        enough        spring  groundwater
# 22975          good  insufficient  shallow well  groundwater
# ...             ...           ...           ...          ...
# 9376           good  insufficient      borehole  groundwater
# 20299          good        enough      borehole  groundwater
# 6503           good           dry        spring  groundwater
# 54761          good        enough      borehole  groundwater
# 1976           good  insufficient      borehole  groundwater
#
#           waterpoint_type installer_new    funder_new
# 49542  communal standpipe         other    world bank
# 34069  communal standpipe           dwe         tasaf
# 50671  communal standpipe         other        church
# 47695  communal standpipe     community    government
# 22975           hand pump  world vision  world vision
# ...                   ...           ...           ...
# 9376   communal standpipe           dwe         tasaf
# 20299               other          finw          finw
# 6503   communal standpipe         other         other
# 54761           hand pump           dwe        danida
# 1976            hand pump         other         other
#
# [33244 rows x 20 columns]

# %% [markdown]
# # Encode Features

# %%
## one hot encode categoricals training set
X_train_ohe = pd.get_dummies(X_train[col_names_ohe])
X_train_ohe.head()
# Out:
#        amount_tsh_(-1, 0]  amount_tsh_(0, 20]  amount_tsh_(20, 350000]  \
# 49542                   0                   0                        1
# 34069                   0                   1                        0
# 50671                   0                   0                        1
# 47695                   0                   0                        1
# 22975                   1                   0                        0
#
#        basin_Internal  basin_Lake Nyasa  basin_Lake Rukwa  \
# 49542               0                 0                 0
# 34069               0                 0                 0
# 50671               0                 0                 0
# 47695               0                 1                 0
# 22975               1                 0                 0
#
#        basin_Lake Tanganyika  basin_Lake Victoria  basin_Pangani  \
# 49542                      0                    0              0
# 34069                      0                    0              1
# 50671                      0                    0              0
# 47695                      0                    0              0
# 22975                      0                    0              0
#
#        basin_Rufiji  ...  funder_new_kkkt  funder_new_norad  funder_new_other  \
# 49542             0  ...                0                 0                 0
# 34069             0  ...                0                 0                 0
# 50671             1  ...                0                 0                 0
# 47695             0  ...                0                 0                 0
# 22975             0  ...                0                 0                 0
#
#        funder_new_private individual  funder_new_rwssp  funder_new_tasaf  \
# 49542                              0                 0                 0
# 34069                              0                 0                 1
# 50671                              0                 0                 0
# 47695                              0                 0                 0
# 22975                              0                 0                 0
#
#        funder_new_tcrs  funder_new_unicef  funder_new_world bank  \
# 49542                0                  0                      1
# 34069                0                  0                      0
# 50671                0                  0                      0
# 47695                0                  0                      0
# 22975                0                  0                      0
#
#        funder_new_world vision
# 49542                        0
# 34069                        0
# 50671                        0
# 47695                        0
# 22975                        1
#
# [5 rows x 196 columns]

# %%
X_train.head()
# Out:
#          amount_tsh  longitude  latitude        basin region_code  \
# 49542  (20, 350000]  37.775982 -7.097974  Wami / Ruvu           5
# 34069       (0, 20]  38.660796 -5.805560      Pangani           4
# 50671  (20, 350000]  35.931710 -8.269781       Rufiji          11
# 47695  (20, 350000]  33.963904 -9.244679   Lake Nyasa          11
# 22975       (-1, 0]  34.048313 -3.514827     Internal          17
#
#       district_code     lga  permit construction_year extraction_type_group  \
# 49542             2   other       1  (2005.0, 2015.0]               gravity
# 34069             6   other       0  (2005.0, 2015.0]           submersible
# 50671             7   other       1  (2005.0, 2015.0]               gravity
# 47695             3  makete       0  (1985.0, 2005.0]               gravity
# 22975             2   maswa       0               NaN           nira/tanira
#
#       management management_group         payment quality_group      quantity  \
# 49542        vwc       user-group     pay monthly          good  insufficient
# 34069        vwc       user-group  pay per bucket         salty  insufficient
# 50671        vwc       user-group    pay annually          good        enough
# 47695        vwc       user-group     pay monthly          good        enough
# 22975        wug       user-group           other          good  insufficient
#
#         source_type source_class     waterpoint_type installer_new  \
# 49542    river/lake      surface  communal standpipe         other
# 34069      borehole  groundwater  communal standpipe           dwe
# 50671        spring  groundwater  communal standpipe         other
# 47695        spring  groundwater  communal standpipe     community
# 22975  shallow well  groundwater           hand pump  world vision
#
#          funder_new
# 49542    world bank
# 34069         tasaf
# 50671        church
# 47695    government
# 22975  world vision

# %%
## Concatenate OHE columns with original dataframe, dropping OHE original features
X_train = pd.concat([X_train, X_train_ohe], axis=1)
X_train.drop(col_names_ohe, axis=1, inplace=True)
X_train.head()
# Out:
#        longitude  latitude  permit  amount_tsh_(-1, 0]  amount_tsh_(0, 20]  \
# 49542  37.775982 -7.097974       1                   0                   0
# 34069  38.660796 -5.805560       0                   0                   1
# 50671  35.931710 -8.269781       1                   0                   0
# 47695  33.963904 -9.244679       0                   0                   0
# 22975  34.048313 -3.514827       0                   1                   0
#
#        amount_tsh_(20, 350000]  basin_Internal  basin_Lake Nyasa  \
# 49542                        1               0                 0
# 34069                        0               0                 0
# 50671                        1               0                 0
# 47695                        1               0                 1
# 22975                        0               1                 0
#
#        basin_Lake Rukwa  basin_Lake Tanganyika  ...  funder_new_kkkt  \
# 49542                 0                      0  ...                0
# 34069                 0                      0  ...                0
# 50671                 0                      0  ...                0
# 47695                 0                      0  ...                0
# 22975                 0                      0  ...                0
#
#        funder_new_norad  funder_new_other  funder_new_private individual  \
# 49542                 0                 0                              0
# 34069                 0                 0                              0
# 50671                 0                 0                              0
# 47695                 0                 0                              0
# 22975                 0                 0                              0
#
#        funder_new_rwssp  funder_new_tasaf  funder_new_tcrs  funder_new_unicef  \
# 49542                 0                 0                0                  0
# 34069                 0                 1                0                  0
# 50671                 0                 0                0                  0
# 47695                 0                 0                0                  0
# 22975                 0                 0                0                  0
#
#        funder_new_world bank  funder_new_world vision
# 49542                      1                        0
# 34069                      0                        0
# 50671                      0                        0
# 47695                      0                        0
# 22975                      0                        1
#
# [5 rows x 199 columns]

# %%
## one hot encode categoricals test set
X_test_ohe = pd.get_dummies(X_test[col_names_ohe])
X_test_ohe.head()
# Out:
#        amount_tsh_(-1, 0]  amount_tsh_(0, 20]  amount_tsh_(20, 350000]  \
# 52314                   1                   0                        0
# 37860                   1                   0                        0
# 26399                   1                   0                        0
# 47894                   1                   0                        0
# 936                     0                   0                        1
#
#        basin_Internal  basin_Lake Nyasa  basin_Lake Rukwa  \
# 52314               0                 0                 1
# 37860               0                 0                 0
# 26399               0                 0                 0
# 47894               0                 0                 0
# 936                 0                 0                 0
#
#        basin_Lake Tanganyika  basin_Lake Victoria  basin_Pangani  \
# 52314                      0                    0              0
# 37860                      0                    1              0
# 26399                      0                    0              0
# 47894                      0                    0              0
# 936                        0                    0              0
#
#        basin_Rufiji  ...  funder_new_kkkt  funder_new_norad  funder_new_other  \
# 52314             0  ...                0                 0                 1
# 37860             0  ...                0                 0                 1
# 26399             1  ...                0                 0                 1
# 47894             0  ...                0                 0                 1
# 936               1  ...                0                 0                 0
#
#        funder_new_private individual  funder_new_rwssp  funder_new_tasaf  \
# 52314                              0                 0                 0
# 37860                              0                 0                 0
# 26399                              0                 0                 0
# 47894                              0                 0                 0
# 936                                0                 0                 0
#
#        funder_new_tcrs  funder_new_unicef  funder_new_world bank  \
# 52314                0                  0                      0
# 37860                0                  0                      0
# 26399                0                  0                      0
# 47894                0                  0                      0
# 936                  0                  1                      0
#
#        funder_new_world vision
# 52314                        0
# 37860                        0
# 26399                        0
# 47894                        0
# 936                          0
#
# [5 rows x 195 columns]

# %%
## Concatenate OHE columns with original dataframe, dropping OHE original features
X_test = pd.concat([X_test, X_test_ohe], axis=1)
X_test.drop(col_names_ohe, axis=1, inplace=True)
X_test.head()
# Out:
#        longitude  latitude  permit  amount_tsh_(-1, 0]  amount_tsh_(0, 20]  \
# 52314  32.069598 -8.691708       0                   1                   0
# 37860  34.097501 -1.427451       0                   1                   0
# 26399  33.853597 -8.825378       1                   1                   0
# 47894  37.078369 -6.795748       1                   1                   0
# 936    34.680117 -9.102874       1                   0                   0
#
#        amount_tsh_(20, 350000]  basin_Internal  basin_Lake Nyasa  \
# 52314                        0               0                 0
# 37860                        0               0                 0
# 26399                        0               0                 0
# 47894                        0               0                 0
# 936                          1               0                 0
#
#        basin_Lake Rukwa  basin_Lake Tanganyika  ...  funder_new_kkkt  \
# 52314                 1                      0  ...                0
# 37860                 0                      0  ...                0
# 26399                 0                      0  ...                0
# 47894                 0                      0  ...                0
# 936                   0                      0  ...                0
#
#        funder_new_norad  funder_new_other  funder_new_private individual  \
# 52314                 0                 1                              0
# 37860                 0                 1                              0
# 26399                 0                 1                              0
# 47894                 0                 1                              0
# 936                   0                 0                              0
#
#        funder_new_rwssp  funder_new_tasaf  funder_new_tcrs  funder_new_unicef  \
# 52314                 0                 0                0                  0
# 37860                 0                 0                0                  0
# 26399                 0                 0                0                  0
# 47894                 0                 0                0                  0
# 936                   0                 0                0                  1
#
#        funder_new_world bank  funder_new_world vision
# 52314                      0                        0
# 37860                      0                        0
# 26399                      0                        0
# 47894                      0                        0
# 936                        0                        0
#
# [5 rows x 198 columns]

# %%
# not_included = list(set(list(X_train)) - set(list(X_test))) + list(set(list(X_test)) - set(list(X_train)))

# print(not_included)

# %%
X_test_deletions = list(set(list(X_test)) - set(list(X_train)))
X_test_deletions
# Out:
# ['region_code_40']

# %%
X_train_deletions = list(set(list(X_train)) - set(list(X_test))) 
X_train_deletions
# Out:
# ['waterpoint_type_dam', 'district_code_67']

# %%
for col in X_train_deletions:
    del X_train[col]
X_train.columns
# Out:
# Index(['longitude', 'latitude', 'permit', 'amount_tsh_(-1, 0]',
#        'amount_tsh_(0, 20]', 'amount_tsh_(20, 350000]', 'basin_Internal',
#        'basin_Lake Nyasa', 'basin_Lake Rukwa', 'basin_Lake Tanganyika',
#        ...
#        'funder_new_kkkt', 'funder_new_norad', 'funder_new_other',
#        'funder_new_private individual', 'funder_new_rwssp', 'funder_new_tasaf',
#        'funder_new_tcrs', 'funder_new_unicef', 'funder_new_world bank',
#        'funder_new_world vision'],
#       dtype='object', length=197)

# %%
X_train.shape
# Out:
# (33244, 197)

# %%
for col in X_test_deletions:
    del X_test[col]
X_test.columns
# Out:
# Index(['longitude', 'latitude', 'permit', 'amount_tsh_(-1, 0]',
#        'amount_tsh_(0, 20]', 'amount_tsh_(20, 350000]', 'basin_Internal',
#        'basin_Lake Nyasa', 'basin_Lake Rukwa', 'basin_Lake Tanganyika',
#        ...
#        'funder_new_kkkt', 'funder_new_norad', 'funder_new_other',
#        'funder_new_private individual', 'funder_new_rwssp', 'funder_new_tasaf',
#        'funder_new_tcrs', 'funder_new_unicef', 'funder_new_world bank',
#        'funder_new_world vision'],
#       dtype='object', length=197)

# %%
X_test.shape
# Out:
# (14248, 197)

# %%
di = {0: 0, 'functional': 1, 'non functional': 2, 'functional needs repair':3 }
y_train.replace(di, inplace=True)

# %%
di = {0: 0, 'functional': 1, 'non functional': 2, 'functional needs repair':3 }
y_test.replace(di, inplace=True)

# %% [markdown]
# ## Delete 'other' columns OHE

# %% [markdown]
# For Text data which was too low incidence to make its own group we consolidated it in 'other' groups. This is noisy data that should be deleted.

# %%
other_cols_train = [col for col in X_train.columns if 'other' in col]
other_cols_train
# Out:
# ['lga_other',
#  'extraction_type_group_other',
#  'extraction_type_group_other handpump',
#  'extraction_type_group_other motorpump',
#  'management_other',
#  'management_other - school',
#  'management_group_other',
#  'payment_other',
#  'source_type_other',
#  'waterpoint_type_other',
#  'installer_new_other',
#  'funder_new_other']

# %%
X_train = X_train.drop(other_cols_train, axis=1)
X_train.columns
# Out:
# Index(['longitude', 'latitude', 'permit', 'amount_tsh_(-1, 0]',
#        'amount_tsh_(0, 20]', 'amount_tsh_(20, 350000]', 'basin_Internal',
#        'basin_Lake Nyasa', 'basin_Lake Rukwa', 'basin_Lake Tanganyika',
#        ...
#        'funder_new_hesawa', 'funder_new_kkkt', 'funder_new_norad',
#        'funder_new_private individual', 'funder_new_rwssp', 'funder_new_tasaf',
#        'funder_new_tcrs', 'funder_new_unicef', 'funder_new_world bank',
#        'funder_new_world vision'],
#       dtype='object', length=185)

# %%
other_cols_test = [col for col in X_test.columns if 'other' in col]
other_cols_test
# Out:
# ['lga_other',
#  'extraction_type_group_other',
#  'extraction_type_group_other handpump',
#  'extraction_type_group_other motorpump',
#  'management_other',
#  'management_other - school',
#  'management_group_other',
#  'payment_other',
#  'source_type_other',
#  'waterpoint_type_other',
#  'installer_new_other',
#  'funder_new_other']

# %%
X_test = X_test.drop(other_cols_test, axis=1)
X_train.columns
# Out:
# Index(['longitude', 'latitude', 'permit', 'amount_tsh_(-1, 0]',
#        'amount_tsh_(0, 20]', 'amount_tsh_(20, 350000]', 'basin_Internal',
#        'basin_Lake Nyasa', 'basin_Lake Rukwa', 'basin_Lake Tanganyika',
#        ...
#        'funder_new_hesawa', 'funder_new_kkkt', 'funder_new_norad',
#        'funder_new_private individual', 'funder_new_rwssp', 'funder_new_tasaf',
#        'funder_new_tcrs', 'funder_new_unicef', 'funder_new_world bank',
#        'funder_new_world vision'],
#       dtype='object', length=185)

# %% [markdown]
# # Model Development

# %% [markdown]
# ## Baseline models

# %% [markdown]
# ## Random Forest Classifier

# %%
# Instantiate and fit the RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=10,class_weight='balanced')
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=10)

# %%
# accuracy_score(y_train, y_pred)

# %%
# print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
training_start = time.perf_counter()
rfc.fit(X_train, y_train)
training_end = time.perf_counter()
prediction_start = time.perf_counter()
y_pred = rfc.predict(X_test)
prediction_end = time.perf_counter()
acc_rfc = (y_pred == y_test).sum().astype(float) / len(y_pred)*100
rfc_train_time = training_end-training_start
rfc_prediction_time = prediction_end-prediction_start
print("Scikit-Learn's Random Forest Classifier's prediction accuracy is: %3.2f" % (acc_rfc))
print("Time consumed for training: %4.3f seconds" % (rfc_train_time))
print("Time consumed for prediction: %6.5f seconds" % (rfc_prediction_time))
# Out:
# Scikit-Learn's Random Forest Classifier's prediction accuracy is: 47.48
# Time consumed for training: 1.125 seconds
# Time consumed for prediction: 0.08446 seconds

# %%
# View confusion matrix for test data and predictions
confusion_matrix(y_test, y_pred)
# Out:
# array([[4925, 2448,  341],
#        [3518, 1794,  229],
#        [ 630,  317,   46]])

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, y_pred, labels=[1,2,3]))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.54      0.64      0.59      7714
#            2       0.39      0.32      0.36      5541
#            3       0.07      0.05      0.06       993
#
#     accuracy                           0.47     14248
#    macro avg       0.34      0.34      0.33     14248
# weighted avg       0.45      0.47      0.46     14248

# %% [markdown]
# ### Check for Overfit

# %%
rfc_training_preds = rfc.predict(X_train)
rfc_training_accuracy = accuracy_score(y_train, rfc_training_preds)

rfc_val_preds = rfc.predict(X_test) # y_hat
rfc_val_accuracy = accuracy_score(y_test, rfc_val_preds)
print(rfc_training_accuracy)
print(rfc_val_accuracy)
# Out:
# 0.9484418240885574
# 0.4748034811903425

# %% [markdown]
# Focus on what the Tanzanian W ministry wants to do
# How can we tell which ones are broken
# Emphasize Business Problem
# Actionable Insights

# %% [markdown]
# ### Feature Importance

# %%
# create list so that random forest model important features are named
rfc_columns = list(X_train.columns)

# %%
feat_importances = pd.Series(rfc.feature_importances_, index = rfc_columns)
feat_importances.nlargest(20).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Model reiteration

# %%
feat_importances.nlargest(10)
# Out:
# latitude                              0.280499
# longitude                             0.280011
# quantity_enough                       0.014575
# quantity_insufficient                 0.013436
# payment_never pay                     0.011983
# construction_year_(1985, 2005]        0.011915
# installer_new_dwe                     0.011590
# construction_year_(2005, 2015]        0.011030
# permit                                0.010711
# waterpoint_type_communal standpipe    0.010462
# dtype: float64

# %%
# Features for second iteration of Random Forest Model - train
rf2_feats = ['latitude','longitude','quantity_enough','quantity_insufficient','construction_year_(1985, 2005]','installer_new_dwe',
            'construction_year_(2005, 2015]','funder_new_government','permit','waterpoint_type_communal standpipe'] 
X_train_rf2 = X_train[rf2_feats]

# Features for second iteration of Random Forest Model - test
X_test_rf2 = X_test[rf2_feats]

# %%
rf2_model = RandomForestRegressor()

# Train the model on training data
rf2_model.fit(X_train_rf2, y_train)
# Out:
# RandomForestRegressor()

# %%
# Predict on test data
predictions = rf2_model.predict(X_test_rf2)

# %%
# rfc_training_preds = rf2_model.predict(X_train)
# rfc_training_accuracy = accuracy_score(y_train, rfc_training_preds)

# rfc_val_preds = rf2_model.predict(X_test) # y_hat
# rfc_val_accuracy = accuracy_score(y_test, rfc_val_preds)
# print(rfc_training_accuracy)
# print(rfc_val_accuracy)

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
gb_clf = GradientBoostingClassifier(n_estimators=20)
gb_clf.fit(X_train, y_train)


print("Accuracy score (training): {0:.3f}".format(gb_clf.score(X_train, y_train)))
print("Accuracy score (validation): {0:.3f}".format(gb_clf.score(X_test, y_test)))
# Out:
# Accuracy score (training): 0.548
# Accuracy score (validation): 0.541

# %%
lr_list = [0.05, 0.075, 0.1, 0.25, 0.5, 0.75, 1]

for learning_rate in lr_list:
    gb_clf = GradientBoostingClassifier(n_estimators=20, learning_rate=learning_rate)
    gb_clf.fit(X_train, y_train)

    print("Learning rate: ", learning_rate)
    print("Accuracy score (training): {0:.3f}".format(gb_clf.score(X_train, y_train)))
    print("Accuracy score (validation): {0:.3f}".format(gb_clf.score(X_test, y_test)))
# Out:
# Learning rate:  0.05
# Accuracy score (training): 0.548
# Accuracy score (validation): 0.541
# Learning rate:  0.075
# Accuracy score (training): 0.548
# Accuracy score (validation): 0.541
# Learning rate:  0.1
# Accuracy score (training): 0.548
# Accuracy score (validation): 0.541
# Learning rate:  0.25
# Accuracy score (training): 0.552
# Accuracy score (validation): 0.541
# Learning rate:  0.5
# Accuracy score (training): 0.557
# Accuracy score (validation): 0.538
# Learning rate:  0.75
# Accuracy score (training): 0.562
# Accuracy score (validation): 0.536
# Learning rate:  1
# Accuracy score (training): 0.562
# Accuracy score (validation): 0.533

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### unbalanced

# %%
# Logistic model
log_clf = LogisticRegression(random_state=123, multi_class='multinomial', solver='newton-cg')
log_model = log_clf.fit(X_train, y_train)
log_training_preds = log_clf.predict(X_train)
log_training_accuracy = accuracy_score(y_train, log_training_preds)
log_val_preds = log_clf.predict(X_test) # y_hat
log_val_accuracy = accuracy_score(y_test, log_val_preds)

# %%
#Confusion matrix for Logistic Regression
log_matrix = confusion_matrix(y_test, log_val_preds)
print('Confusion Matrix:\n', log_matrix)
# Out:
# Confusion Matrix:
#  [[7655   59    0]
#  [5494   47    0]
#  [ 986    7    0]]

# %%
print(log_training_accuracy)
print(log_val_accuracy)
# Out:
# 0.5474371315124533
# 0.5405670971364402

# %% [markdown]
# ### balanced

# %%
# Logistic model
log_clf = LogisticRegression(random_state=123, multi_class='multinomial', solver='newton-cg',class_weight='balanced')
log_model = log_clf.fit(X_train, y_train)
log_training_preds = log_clf.predict(X_train)
log_training_accuracy = accuracy_score(y_train, log_training_preds)
log_val_preds = log_clf.predict(X_test) # y_hat
log_val_accuracy = accuracy_score(y_test, log_val_preds)

# %%
#Confusion matrix for Logistic Regression
log_matrix = confusion_matrix(y_test, log_val_preds)
print('Confusion Matrix:\n', log_matrix)
# Out:
# Confusion Matrix:
#  [[2405 2369 2940]
#  [1783 1614 2144]
#  [ 325  302  366]]

# %%
print(log_training_accuracy)
print(log_val_accuracy)
# Out:
# 0.34270845866923355
# 0.30776249298147107

# %% [markdown]
# # Conclusions

# %% [markdown]
# Most Important Factors in water pump functionality:
# - geographic location
# - Water Quantity
# - Construction Year
# - Whether it was permited
# - Who funded the pump
# - Who installed the pump

# %% [markdown]
# # Business Recommendations

# %% [markdown]
# # Notes

# %% [markdown]
# Model Development:
#     Always think about what model needs to provide to the business
#     show overfit and explain factors each model has its own method to address overfit
#      - Tree limiting the depth
#     address  param tuning - grid search cv metric
#     change the metrics to address busines problem
#     create comparison table for models
# Add Future work that can be done section

# %% [markdown]
# - no assumption for normality of residuals
# - class imbalance
#     - setting a balance metric or using smotenc (inside the model there is a parameter called class weights which can be set to balance) logistic reg study group
# - Think about what metrics you are using and why
# - Data Prep is key
# - not as many assumptions for classifiers vs lin reg
# - Do around 3 - 4 different types of models
# - 3 vanilla models, check performance
# - eg rand forest check feat importance
# - xgboost
# - check for overfit
# - see a baseline model usually done with a dummy classifier sklearn.dummies
# - preserve iterations which provide insight or key points of change
